# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import numpy as np
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import json

# %%
amzn = pd.read_csv("Final CSV's/amzn_final.csv", usecols = [1, 2])
appl = pd.read_csv("Final CSV's/appl_final.csv", usecols = [1, 2])
bitcoin = pd.read_csv("Final CSV's/bitcoin_final.csv", usecols = [1, 2])
cpi = pd.read_csv("Final CSV's/cpi_final.csv", usecols = [1, 2])
dow = pd.read_csv("Final CSV's/Dow_Jones_Composite_final.csv", usecols = [1, 2])
eth = pd.read_csv("Final CSV's/eth_final.csv", usecols = [1, 2])
googl = pd.read_csv("Final CSV's/googl_final.csv", usecols = [1, 2])
solana = pd.read_csv("Final CSV's/solana_final.csv", usecols = [1, 2])
msft = pd.read_csv("Final CSV's/msft_final.csv", usecols = [1, 2])
spcomp = pd.read_csv("Final CSV's/spcomp_final.csv", usecols = [1, 2])
nasdaq = pd.read_csv("Final CSV's/NASDAQ_Composite_final.csv", usecols = [1, 2])
gold = pd.read_csv("Final CSV's/spgold_final.csv", usecols = [1, 2])
nvda = pd.read_csv("Final CSV's/nvda_final.csv", usecols = [1, 2])
tsla = pd.read_csv("Final CSV's/tsla_final.csv", usecols = [1, 2])
oil = pd.read_csv("Final CSV's/oil_final.csv", usecols = [1, 2])
xmag = pd.read_csv("Final CSV's/xmag_final.csv", usecols = [1, 2])
silver = pd.read_csv("Final CSV's/silver_final.csv", usecols = [1, 2])

amzn2 = pd.read_csv("Final CSV's/amzn_final.csv", usecols = [1, 3])
appl2 = pd.read_csv("Final CSV's/appl_final.csv", usecols = [1, 3])
bitcoin2 = pd.read_csv("Final CSV's/bitcoin_final.csv", usecols = [1, 3])
cpi2 = pd.read_csv("Final CSV's/cpi_final.csv", usecols = [1, 3])
dow2 = pd.read_csv("Final CSV's/Dow_Jones_Composite_final.csv", usecols = [1, 3])
eth2 = pd.read_csv("Final CSV's/eth_final.csv", usecols = [1, 3])
googl2 = pd.read_csv("Final CSV's/googl_final.csv", usecols = [1, 3])
solana2 = pd.read_csv("Final CSV's/solana_final.csv", usecols = [1, 3])
msft2 = pd.read_csv("Final CSV's/msft_final.csv", usecols = [1, 3])
spcomp2 = pd.read_csv("Final CSV's/spcomp_final.csv", usecols = [1, 3])
nasdaq2 = pd.read_csv("Final CSV's/NASDAQ_Composite_final.csv", usecols = [1, 3])
gold2 = pd.read_csv("Final CSV's/spgold_final.csv", usecols = [1, 3])
nvda2 = pd.read_csv("Final CSV's/nvda_final.csv", usecols = [1, 3])
tsla2 = pd.read_csv("Final CSV's/tsla_final.csv", usecols = [1, 3])
oil2 = pd.read_csv("Final CSV's/oil_final.csv", usecols = [1, 3])
xmag2 = pd.read_csv("Final CSV's/xmag_final.csv", usecols = [1, 3])
silver2 = pd.read_csv("Final CSV's/silver_final.csv", usecols = [1, 3])

# %%
data = pd.merge(amzn, appl, how = "outer", on = "Date")
data = pd.merge(data, bitcoin, how = "outer", on = "Date")
data = pd.merge(data, dow, how = "outer", on = "Date")
data = pd.merge(data, eth, how = "outer", on = "Date")
data = pd.merge(data, googl, how = "outer", on = "Date")
data = pd.merge(data, solana, how = "outer", on = "Date")
data = pd.merge(data, msft, how = "outer", on = "Date")
data = pd.merge(data, spcomp, how = "outer", on = "Date")
data = pd.merge(data, nasdaq, how = "outer", on = "Date")
data = pd.merge(data, gold, how = "outer", on = "Date")
data = pd.merge(data, nvda, how = "outer", on = "Date")
data = pd.merge(data, tsla, how = "outer", on = "Date")
data = pd.merge(data, oil, how = "outer", on = "Date")
data = pd.merge(data, xmag, how = "outer", on = "Date")
data = pd.merge(data, silver, how = "outer", on = "Date")
data
# Out:
#              Date  AMZN Price  APPL Price  Bitcoin Price  \
# 0      01-01-2011         NaN         NaN         0.3000
# 1      01-01-2012         NaN         NaN         5.2677
# 2      01-01-2013         NaN         NaN        13.3041
# 3      01-01-2014         NaN         NaN       771.4000
# 4      01-01-2015         NaN         NaN       314.1360
# ...           ...         ...         ...            ...
# 12382  12-31-2022         NaN         NaN     16538.3479
# 12383  12-31-2023         NaN         NaN     42224.0900
# 12384  12-31-2024      219.39      250.42     93631.3000
# 12385  12-31-2025      230.82      271.86     87559.9000
# 12386  12-31-2025      230.82      271.86     87559.9000
#
#        Dow Jones Composite Price  Ethereum Price  META Price  Solana Price  \
# 0                            NaN             NaN         NaN           NaN
# 1                            NaN             NaN         NaN           NaN
# 2                            NaN             NaN         NaN           NaN
# 3                            NaN             NaN         NaN           NaN
# 4                            NaN        0.690215         NaN           NaN
# ...                          ...             ...         ...           ...
# 12382                        NaN             NaN         NaN         9.870
# 12383                        NaN     2281.870000         NaN       101.720
# 12384                   42544.22     3346.340000      585.51       189.610
# 12385                   48063.29     2975.240000      660.09       124.875
# 12386                   48063.29     2975.240000      660.09       124.875
#
#        MSFT Price  S&P 500 Composite Price  NASDAQ Composite Price  \
# 0             NaN                      NaN                     NaN
# 1             NaN                      NaN                     NaN
# 2             NaN                      NaN                     NaN
# 3             NaN                      NaN                     NaN
# 4             NaN                      NaN                     NaN
# ...           ...                      ...                     ...
# 12382         NaN                      NaN                     NaN
# 12383         NaN                      NaN                     NaN
# 12384      421.50                  5881.63                19310.79
# 12385      483.62                  6845.50                23241.99
# 12386      483.62                  6845.50                23241.99
#
#        S&P Gold Price  NVDA Price  TSLA Price  Oil Futures Price  XMAG Price  \
# 0                 NaN         NaN         NaN                NaN         NaN
# 1                 NaN         NaN         NaN                NaN         NaN
# 2                 NaN         NaN         NaN                NaN         NaN
# 3                 NaN         NaN         NaN                NaN         NaN
# 4                 NaN         NaN         NaN                NaN         NaN
# ...               ...         ...         ...                ...         ...
# 12382             NaN         NaN         NaN                NaN         NaN
# 12383             NaN         NaN         NaN                NaN         NaN
# 12384         1537.61      134.29      403.84              74.58       19.62
# 12385         2527.42      186.50      449.72              61.35       22.57
# 12386         2527.42      186.50      449.72              61.35       22.57
#
#        Silver Price
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 12382           NaN
# 12383           NaN
# 12384     28.940001
# 12385     71.139999
# 12386     70.603000
#
# [12387 rows x 17 columns]

# %%
data["Date"] = pd.to_datetime(data["Date"], format = "%m-%d-%Y")
data = data.sort_values(by = "Date")
data = data.reset_index(drop = True)
data = data.set_index("Date", drop = True)
data
# Out:
#             AMZN Price  APPL Price  Bitcoin Price  Dow Jones Composite Price  \
# Date
# 1987-05-20         NaN         NaN            NaN                        NaN
# 1987-05-21         NaN         NaN            NaN                        NaN
# 1987-05-22         NaN         NaN            NaN                        NaN
# 1987-05-25         NaN         NaN            NaN                        NaN
# 1987-05-26         NaN         NaN            NaN                        NaN
# ...                ...         ...            ...                        ...
# 2026-04-06      212.79      258.86        68747.8                   46669.88
# 2026-04-07         NaN         NaN            NaN                        NaN
# 2026-04-08         NaN         NaN            NaN                        NaN
# 2026-04-09         NaN         NaN            NaN                        NaN
# 2026-04-10         NaN         NaN            NaN                        NaN
#
#             Ethereum Price  META Price  Solana Price  MSFT Price  \
# Date
# 1987-05-20             NaN         NaN           NaN         NaN
# 1987-05-21             NaN         NaN           NaN         NaN
# 1987-05-22             NaN         NaN           NaN         NaN
# 1987-05-25             NaN         NaN           NaN         NaN
# 1987-05-26             NaN         NaN           NaN         NaN
# ...                    ...         ...           ...         ...
# 2026-04-06         2107.81      573.02           NaN      372.88
# 2026-04-07             NaN         NaN           NaN         NaN
# 2026-04-08             NaN         NaN           NaN         NaN
# 2026-04-09             NaN         NaN           NaN         NaN
# 2026-04-10             NaN         NaN           NaN         NaN
#
#             S&P 500 Composite Price  NASDAQ Composite Price  S&P Gold Price  \
# Date
# 1987-05-20                      NaN                     NaN             NaN
# 1987-05-21                      NaN                     NaN             NaN
# 1987-05-22                      NaN                     NaN             NaN
# 1987-05-25                      NaN                     NaN             NaN
# 1987-05-26                      NaN                     NaN             NaN
# ...                             ...                     ...             ...
# 2026-04-06                  6611.83                21996.34             NaN
# 2026-04-07                      NaN                     NaN             NaN
# 2026-04-08                      NaN                     NaN             NaN
# 2026-04-09                      NaN                     NaN             NaN
# 2026-04-10                      NaN                     NaN             NaN
#
#             NVDA Price  TSLA Price  Oil Futures Price  XMAG Price  \
# Date
# 1987-05-20         NaN         NaN              18.63         NaN
# 1987-05-21         NaN         NaN              18.45         NaN
# 1987-05-22         NaN         NaN              18.55         NaN
# 1987-05-25         NaN         NaN              18.60         NaN
# 1987-05-26         NaN         NaN              18.63         NaN
# ...                ...         ...                ...         ...
# 2026-04-06      177.64      352.82                NaN     22.5047
# 2026-04-07         NaN         NaN                NaN     22.5000
# 2026-04-08         NaN         NaN                NaN     23.0421
# 2026-04-09         NaN         NaN                NaN     23.1250
# 2026-04-10         NaN         NaN                NaN     22.9731
#
#             Silver Price
# Date
# 1987-05-20           NaN
# 1987-05-21           NaN
# 1987-05-22           NaN
# 1987-05-25           NaN
# 1987-05-26           NaN
# ...                  ...
# 2026-04-06        72.847
# 2026-04-07           NaN
# 2026-04-08           NaN
# 2026-04-09           NaN
# 2026-04-10           NaN
#
# [12387 rows x 16 columns]

# %%
data_range = data.loc["2016-12-31" : "2025-12-31"]
data_range
# Out:
#             AMZN Price  APPL Price  Bitcoin Price  Dow Jones Composite Price  \
# Date
# 2016-12-31         NaN         NaN        963.599                        NaN
# 2017-01-01         NaN         NaN        997.777                        NaN
# 2017-01-02         NaN         NaN       1021.790                        NaN
# 2017-01-03     37.6835     29.0375       1044.080                   19881.76
# 2017-01-04     37.8590     29.0050       1153.540                   19942.16
# ...                ...         ...            ...                        ...
# 2025-12-29    232.0700    273.7600      87323.600                   48461.93
# 2025-12-30    232.5300    273.0800      88382.900                   48367.06
# 2025-12-30    232.5300    273.0800      88382.900                   48367.06
# 2025-12-31    230.8200    271.8600      87559.900                   48063.29
# 2025-12-31    230.8200    271.8600      87559.900                   48063.29
#
#             Ethereum Price  META Price  Solana Price  MSFT Price  \
# Date
# 2016-12-31        8.000000         NaN           NaN         NaN
# 2017-01-01       10.732100         NaN           NaN         NaN
# 2017-01-02        8.370000         NaN           NaN         NaN
# 2017-01-03      292.463013      116.86           NaN       62.58
# 2017-01-04      300.468994      118.69           NaN       62.30
# ...                    ...         ...           ...         ...
# 2025-12-29     2949.410000      658.69       123.950      487.10
# 2025-12-30     2973.280000      665.95       125.597      487.48
# 2025-12-30     2973.280000      665.95       125.597      487.48
# 2025-12-31     2975.240000      660.09       124.875      483.62
# 2025-12-31     2975.240000      660.09       124.875      483.62
#
#             S&P 500 Composite Price  NASDAQ Composite Price  S&P Gold Price  \
# Date
# 2016-12-31                      NaN                     NaN             NaN
# 2017-01-01                      NaN                     NaN             NaN
# 2017-01-02                      NaN                     NaN             NaN
# 2017-01-03                  2257.83                 5429.08          676.53
# 2017-01-04                  2270.75                 5477.00          678.45
# ...                             ...                     ...             ...
# 2025-12-29                  6905.74                23474.35         2528.88
# 2025-12-30                  6896.24                23419.08         2553.74
# 2025-12-30                  6896.24                23419.08         2553.74
# 2025-12-31                  6845.50                23241.99         2527.42
# 2025-12-31                  6845.50                23241.99         2527.42
#
#             NVDA Price  TSLA Price  Oil Futures Price  XMAG Price  \
# Date
# 2016-12-31         NaN         NaN                NaN         NaN
# 2017-01-01         NaN         NaN                NaN         NaN
# 2017-01-02         NaN         NaN                NaN         NaN
# 2017-01-03      2.5503     14.4660              55.05         NaN
# 2017-01-04      2.6098     15.1327              54.57         NaN
# ...                ...         ...                ...         ...
# 2025-12-29    188.2200    459.6400              63.10     22.7525
# 2025-12-30    187.5400    454.4300              62.30     22.6700
# 2025-12-30    187.5400    454.4300              62.30     22.6700
# 2025-12-31    186.5000    449.7200              61.35     22.5700
# 2025-12-31    186.5000    449.7200              61.35     22.5700
#
#             Silver Price
# Date
# 2016-12-31           NaN
# 2017-01-01           NaN
# 2025-12-30      187.54      454.43              62.30     22.6700
# 2025-12-31      186.50      449.72              61.35     22.5700
# 2025-12-31      186.50      449.72              61.35     22.5700
#
#             Silver Price
# Date
# 2024-10-22     34.831001
# 2024-10-23     33.639999
# 2024-10-24     33.611000
# 2024-10-25     33.603001
# 2024-10-26           NaN
# ...                  ...
# 2025-12-29     70.460000
# 2025-12-30     77.374001
# 2025-12-30     77.919000
# 2025-12-31     71.139999
# 2025-12-31     70.603000
#
# [622 rows x 16 columns]

# %%
data2 = pd.merge(amzn2, appl2, how = "outer", on = "Date")
data2 = pd.merge(data2, bitcoin2, how = "outer", on = "Date")
data2 = pd.merge(data2, dow2, how = "outer", on = "Date")
data2 = pd.merge(data2, eth2, how = "outer", on = "Date")
data2 = pd.merge(data2, googl2, how = "outer", on = "Date")
data2 = pd.merge(data2, solana2, how = "outer", on = "Date")
data2 = pd.merge(data2, msft2, how = "outer", on = "Date")
data2 = pd.merge(data2, spcomp2, how = "outer", on = "Date")
data2 = pd.merge(data2, nasdaq2, how = "outer", on = "Date")
data2 = pd.merge(data2, gold2, how = "outer", on = "Date")
data2 = pd.merge(data2, nvda2, how = "outer", on = "Date")
data2 = pd.merge(data2, tsla2, how = "outer", on = "Date")
data2 = pd.merge(data2, oil2, how = "outer", on = "Date")
data2 = pd.merge(data2, xmag2, how = "outer", on = "Date")
data2 = pd.merge(data2, silver2, how = "outer", on = "Date")
data2
# Out:
#              Date  AMZN Percent Change Rate  APPL Percent Change Rate  \
# 0      01-01-2011                       NaN                       NaN
# 1      01-01-2012                       NaN                       NaN
# 2      01-01-2013                       NaN                       NaN
# 3      01-01-2014                       NaN                       NaN
# 4      01-01-2015                       NaN                       NaN
# ...           ...                       ...                       ...
# 12382  12-31-2022                       NaN                       NaN
# 12383  12-31-2023                       NaN                       NaN
# 12384  12-31-2024                 99.136918                 99.294211
# 12385  12-31-2025                 99.264611                 99.553244
# 12386  12-31-2025                 99.264611                 99.553244
#
#        Bitcoin Percent Change Rate  DOW Percent Change Rate  \
# 0                       100.000000                      NaN
# 1                       111.556544                      NaN
# 2                        98.475944                      NaN
# 3                       102.306335                      NaN
# 4                        98.172715                      NaN
# ...                            ...                      ...
# 12382                    99.606089                      NaN
# 12383                   100.059812                      NaN
# 12384                   101.323145                99.930685
# 12385                    99.068824                99.371949
# 12386                    99.068824                99.371949
#
#        Ethereum Percent Change Rate  META Percent Change Rate  \
# 0                               NaN                       NaN
# 1                               NaN                       NaN
# 2                               NaN                       NaN
# 3                               NaN                       NaN
# 4                               NaN                       NaN
# ...                             ...                       ...
# 12382                    100.000000                       NaN
# 12383                     99.571930                       NaN
# 12384                    100.300331                 99.030850
# 12385                    100.065920                 99.120054
# 12386                    100.065920                 99.120054
#
#        Solana Percent Change Rate  MSFT Percent Change Rate  \
# 0                             NaN                       NaN
# 1                             NaN                       NaN
# 2                             NaN                       NaN
# 3                             NaN                       NaN
# 4                             NaN                       NaN
# ...                           ...                       ...
# 12382                  102.047146                       NaN
# 12383                   99.823356                       NaN
# 12384                  100.594196                 99.216157
# 12385                   99.425146                 99.208173
# 12386                   99.425146                 99.208173
#
#        S&P 500 Composite Percent Change Rate  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 12382                                    NaN
# 12383                                    NaN
# 12384                              99.571521
# 12385                              99.264237
# 12386                              99.264237
#
#        NASDAQ Composite Percent Change Rate  S&P Gold Percent Change Rate  \
# 0                                       NaN                           NaN
# 1                                       NaN                           NaN
# 2                                       NaN                           NaN
# 3                                       NaN                           NaN
# 4                                       NaN                           NaN
# ...                                     ...                           ...
# 12382                                   NaN                           NaN
# 12383                                   NaN                           NaN
# 12384                             99.096875                    100.874511
# 12385                             99.243822                     98.969355
# 12386                             99.243822                     98.969355
#
#        NVDA Percent Change Rate  TSLA Percent Change Rate  \
# 0                           NaN                       NaN
# 1                           NaN                       NaN
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN
# ...                         ...                       ...
# 12382                       NaN                       NaN
# 12383                       NaN                       NaN
# 12384                 97.672558                 96.749000
# 12385                 99.445452                 98.963537
# 12386                 99.445452                 98.963537
#
#        Oil Percent Change Rate  XMAG Percent Change Rate  \
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
# ...                        ...                       ...
# 12382                      NaN                       NaN
# 12383                      NaN                       NaN
# 12384               100.457974                 99.695122
# 12385                98.475120                 99.558888
# 12386                98.475120                 99.558888
#
#        Silver Percent Change Rate
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ...                           ...
# 12382                         NaN
# 12383                         NaN
# 12384                   99.429670
# 12385                   91.943029
# 12386                   90.610762
#
# [12387 rows x 17 columns]

# %%
data2["Date"] = pd.to_datetime(data2["Date"], format = "%m-%d-%Y")
data2 = data2.sort_values(by = "Date")
data2 = data2.reset_index(drop = True)
data2 = data2.set_index("Date")
data2
# Out:
#             AMZN Percent Change Rate  APPL Percent Change Rate  \
# Date
# 1987-05-20                       NaN                       NaN
# 1987-05-21                       NaN                       NaN
# 1987-05-22                       NaN                       NaN
# 1987-05-25                       NaN                       NaN
# 1987-05-26                       NaN                       NaN
# ...                              ...                       ...
# 2026-04-06                101.439672                101.148796
# 2026-04-07                       NaN                       NaN
# 2026-04-08                       NaN                       NaN
# 2026-04-09                       NaN                       NaN
# 2026-04-10                       NaN                       NaN
#
#             Bitcoin Percent Change Rate  DOW Percent Change Rate  \
# Date
# 1987-05-20                          NaN                      NaN
# 1987-05-21                          NaN                      NaN
# 1987-05-22                          NaN                      NaN
# 1987-05-25                          NaN                      NaN
# 1987-05-26                          NaN                      NaN
# ...                                 ...                      ...
# 2026-04-06                    99.509457               100.355255
# 2026-04-07                          NaN                      NaN
# 2026-04-08                          NaN                      NaN
# 2026-04-09                          NaN                      NaN
# 2026-04-10                          NaN                      NaN
#
#             Ethereum Percent Change Rate  META Percent Change Rate  \
# Date
# 1987-05-20                           NaN                       NaN
# 1987-05-21                           NaN                       NaN
# 1987-05-22                           NaN                       NaN
# 1987-05-25                           NaN                       NaN
# 1987-05-26                           NaN                       NaN
# ...                                  ...                       ...
# 2026-04-06                      99.03726                  99.74933
# 2026-04-07                           NaN                       NaN
# 2026-04-08                           NaN                       NaN
# 2026-04-09                           NaN                       NaN
# 2026-04-10                           NaN                       NaN
#
#             Solana Percent Change Rate  MSFT Percent Change Rate  \
# Date
# 1987-05-20                         NaN                       NaN
# 1987-05-21                         NaN                       NaN
# 1987-05-22                         NaN                       NaN
# 1987-05-25                         NaN                       NaN
# 1987-05-26                         NaN                       NaN
# ...                                ...                       ...
# 2026-04-06                         NaN                 99.844696
# 2026-04-07                         NaN                       NaN
# 2026-04-08                         NaN                       NaN
# 2026-04-09                         NaN                       NaN
# 2026-04-10                         NaN                       NaN
#
#             S&P 500 Composite Percent Change Rate  \
# Date
# 1987-05-20                                    NaN
# 1987-05-21                                    NaN
# 1987-05-22                                    NaN
# 1987-05-25                                    NaN
# 1987-05-26                                    NaN
# ...                                           ...
# 2026-04-06                             100.442676
# 2026-04-07                                    NaN
# 2026-04-08                                    NaN
# 2026-04-09                                    NaN
# 2026-04-10                                    NaN
#
#             NASDAQ Composite Percent Change Rate  \
# Date
# 1987-05-20                                   NaN
# 1987-05-21                                   NaN
# 1987-05-22                                   NaN
# 1987-05-25                                   NaN
# 1987-05-26                                   NaN
# ...                                          ...
# 2026-04-06                            100.535486
# 2026-04-07                                   NaN
# 2026-04-08                                   NaN
# 2026-04-09                                   NaN
# 2026-04-10                                   NaN
#
#             S&P Gold Percent Change Rate  NVDA Percent Change Rate  \
# Date
# 1987-05-20                           NaN                       NaN
# 1987-05-21                           NaN                       NaN
# 1987-05-22                           NaN                       NaN
# 1987-05-25                           NaN                       NaN
# 1987-05-26                           NaN                       NaN
# ...                                  ...                       ...
# 2026-04-06                           NaN                100.140932
# 2026-04-07                           NaN                       NaN
# 2026-04-08                           NaN                       NaN
# 2026-04-09                           NaN                       NaN
# 2026-04-10                           NaN                       NaN
#
#             TSLA Percent Change Rate  Oil Percent Change Rate  \
# Date
# 1987-05-20                       NaN                      NaN
# 1987-05-21                       NaN                99.033816
# 1987-05-22                       NaN               100.542005
# 1987-05-25                       NaN               100.269542
# 1987-05-26                       NaN               100.161290
# ...                              ...                      ...
# 2026-04-06                 97.845198                      NaN
# 2026-04-07                       NaN                      NaN
# 2026-04-08                       NaN                      NaN
# 2026-04-09                       NaN                      NaN
# 2026-04-10                       NaN                      NaN
#
#             XMAG Percent Change Rate  Silver Percent Change Rate
# Date
# 1987-05-20                       NaN                         NaN
# 1987-05-21                       NaN                         NaN
# 1987-05-22                       NaN                         NaN
# 1987-05-25                       NaN                         NaN
# 1987-05-26                       NaN                         NaN
# ...                              ...                         ...
# 2026-04-06                100.479971                   99.894411
# 2026-04-07                 99.979115                         NaN
# 2026-04-08                102.409333                         NaN
# 2026-04-09                100.359776                         NaN
# 2026-04-10                 99.343135                         NaN
#
# [12387 rows x 16 columns]

# %%
data2_range = data2.loc["2016-12-31" : "2025-12-31"]
data2_solana = data2.loc["2020-08-11" : "2025-12-31"]
data2_xmag = data2.loc["2024-10-22" : "2025-12-31"]

# %%
#data.to_csv("Asset Price Data.csv")
#data2.to_csv("Asset Percent Change Data.csv")
#data_range.to_csv("Visualization Analysis Full Price.csv")
#data_solana.to_csv("Visualization Analysis Solana Price.csv")
#data_xmag.to_csv("Visualization Analysis XMAG Price.csv")
#data2_range.to_csv("Visualization Analysis Full Percent.csv")
#data2_solana.to_csv("Visualization Analysis Solana Percent.csv")
#data2_xmag.to_csv("Visualization Analysis XMAG Percent.csv")
