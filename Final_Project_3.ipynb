# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import numpy as np
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import json

# %%
bitcoin1 = pd.read_csv("Bitcoin 1.csv")
bitcoin2 = pd.read_csv("Bitcoin 2.csv")
oil = pd.read_csv("Brent Oil Futures Daily.csv")
cpi = pd.read_csv("CPIAUCSL.csv")
dow = pd.read_excel("Dow Jones Composite.xlsx")
eth1 = pd.read_csv("Ethereum 1.csv")
eth2 = pd.read_csv("Ethereum 2.csv")
eth3 = pd.read_csv("Ethereum 3.csv")
eth4 = pd.read_csv("Ethereum 4.csv")
gold = pd.read_csv("Gold New.csv")
appl = pd.read_csv("NASDAQ APPL.csv")
amzn = pd.read_csv("NASDAQ AMZN.csv")
comp = pd.read_csv("NASDAQ Composite.csv")
googl = pd.read_csv("NASDAQ GOOGL.csv")
meta = pd.read_csv("NASDAQ META.csv")
msft = pd.read_csv("NASDAQ MSFT.csv")
nvda = pd.read_csv("NASDAQ NVDA.csv")
tsla = pd.read_csv("NASDAQ TSLA.csv")
spcomp2 = pd.read_csv("S&P Composite 2.csv")
spcomp1 = pd.read_excel("S&P Composite.xlsx")
spgold = pd.read_csv("S&P GSCI Gold Index.csv")
silver2 = pd.read_csv("Silver 2.csv")
silver1 = pd.read_csv("Silver.csv")
solana1 = pd.read_csv("Solana 1.csv")
solana2 = pd.read_csv("Solana 2.csv")
xmag = pd.read_csv("XMAG.csv")

#This cell creates my dataframes for the excel files that I assembled.

# %%
bitcoin1.head()

#I open bitcoin1 to look at its contents
# Out:
#          Date  Close/Last  Volume     Open     High      Low
# 0  04/06/2026     68747.8     NaN  69099.8  69103.2  68290.9
# 1  04/05/2026     69086.7     NaN  67128.2  69534.5  68794.0
# 2  04/04/2026     67136.0     NaN  66832.5  67304.3  66986.3
# 3  04/03/2026     66787.9     NaN  66450.7  67283.7  66284.3
# 4  04/02/2026     66593.2     NaN  66581.9  66991.4  66284.3

# %%
bitcoin1[["Date", "Close/Last"]]

#I isolate the two columns I want in bitcoin1
# Out:
#             Date  Close/Last
# 0     04/06/2026     68747.8
# 1     04/05/2026     69086.7
# 2     04/04/2026     67136.0
# 3     04/03/2026     66787.9
# 4     04/02/2026     66593.2
# ...          ...         ...
# 2298  03/12/2019      3886.0
# 2299  03/11/2019      3865.1
# 2300  03/10/2019      3915.2
# 2301  03/09/2019      3944.4
# 2302  03/08/2019      3865.9
#
# [2303 rows x 2 columns]

# %%
bitcoin1 = bitcoin1[["Date", "Close/Last"]]
bitcoin1 = bitcoin1.rename(columns = {"Close/Last" : "Price"})
bitcoin1.head()

#I overwrite the larger dataframe with the two columns I want and I rename them
# Out:
#          Date    Price
# 0  04/06/2026  68747.8
# 1  04/05/2026  69086.7
# 2  04/04/2026  67136.0
# 3  04/03/2026  66787.9
# 4  04/02/2026  66593.2

# %%
bitcoin1["Date"] = pd.to_datetime(bitcoin1["Date"], format = "%M/%d/%Y")
bitcoin1["Date"] = bitcoin1["Date"].dt.strftime("%M-%d-%Y")
bitcoin1.head()

#I use the to_datetime function to convert the data in the "Date" column to a datetime data type and use the strftime function to format the column how I want to
# Out:
#          Date    Price
# 0  04-06-2026  68747.8
# 1  04-05-2026  69086.7
# 2  04-04-2026  67136.0
# 3  04-03-2026  66787.9
# 4  04-02-2026  66593.2

# %%
bitcoin2.head()

#I repeated the same steps for bitcoin2
# Out:
#         Start         End      Open      High       Low     Close  \
# 0  2024-04-24  2024-04-25  66553.54  67070.40  63742.73  64291.07
# 1  2024-04-23  2024-04-24  66761.02  67174.02  65884.15  66386.61
# 2  2024-04-22  2024-04-23  64952.02  67180.03  64598.00  66818.89
# 3  2024-04-21  2024-04-22  64875.75  65638.74  64302.47  64896.87
# 4  2024-04-20  2024-04-21  63824.06  65351.33  63321.19  64857.99
#
#          Volume    Market Cap
# 0  1.384736e+11  1.294489e+12
# 1  1.408621e+11  1.308576e+12
# 2  1.400725e+11  1.299703e+12
# 3  1.326574e+11  1.278730e+12
# 4  1.537410e+11  1.263725e+12

# %%
bitcoin2[["Start", "Close"]].head()
# Out:
#         Start     Close
# 0  2024-04-24  64291.07
# 1  2024-04-23  66386.61
# 2  2024-04-22  66818.89
# 3  2024-04-21  64896.87
# 4  2024-04-20  64857.99

# %%
bitcoin2 = bitcoin2[["Start", "Close"]]
bitcoin2 = bitcoin2.rename(columns = {"Start" : "Date", "Close" : "Price"})
bitcoin2.head()
# Out:
#          Date     Price
# 0  2024-04-24  64291.07
# 1  2024-04-23  66386.61
# 2  2024-04-22  66818.89
# 3  2024-04-21  64896.87
# 4  2024-04-20  64857.99

# %%
bitcoin2["Date"] = pd.to_datetime(bitcoin2["Date"], format = "%Y-%m-%d")
bitcoin2["Date"] = bitcoin2["Date"].dt.strftime("%m-%d-%Y")
bitcoin2.head()
# Out:
#          Date     Price
# 0  04-24-2024  64291.07
# 1  04-23-2024  66386.61
# 2  04-22-2024  66818.89
# 3  04-21-2024  64896.87
# 4  04-20-2024  64857.99

# %%
bitcoin = pd.concat([bitcoin1, bitcoin2], axis = "rows")
bitcoin = bitcoin.drop_duplicates(subset = "Date", keep = "last")
bitcoin

#I used the combine_first function to combine the two dataframes into one, thus filling in the data that each was missing.
# Out:
#             Date       Price
# 0     04-06-2026  68747.8000
# 1     04-05-2026  69086.7000
# 2     04-04-2026  67136.0000
# 3     04-03-2026  66787.9000
# 4     04-02-2026  66593.2000
# ...          ...         ...
# 5016  07-31-2010      0.0679
# 5017  07-30-2010      0.0627
# 5018  07-29-2010      0.0699
# 5019  07-28-2010      0.0589
# 5020  07-27-2010      0.0600
#
# [5732 rows x 2 columns]

# %%
bitcoin = bitcoin.rename(columns = {"Price" : "Bitcoin Price"})
bitcoin = bitcoin.iloc[::-1]
bitcoin = bitcoin.reset_index(drop = True)
bitcoin
# Out:
#             Date  Bitcoin Price
# 0     07-27-2010         0.0600
# 1     07-28-2010         0.0589
# 2     07-29-2010         0.0699
# 3     07-30-2010         0.0627
# 4     07-31-2010         0.0679
# ...          ...            ...
# 5727  04-02-2026     66593.2000
# 5728  04-03-2026     66787.9000
# 5729  04-04-2026     67136.0000
# 5730  04-05-2026     69086.7000
# 5731  04-06-2026     68747.8000
#
# [5732 rows x 2 columns]

# %%
bitcoin["Bitcoin Percent Change Rate"] = (1 + bitcoin["Bitcoin Price"].pct_change()) * 100
bitcoin
# Out:
#             Date  Bitcoin Price  Bitcoin Percent Change Rate
# 0     07-27-2010         0.0600                          NaN
# 1     07-28-2010         0.0589                    98.166667
# 2     07-29-2010         0.0699                   118.675722
# 3     07-30-2010         0.0627                    89.699571
# 4     07-31-2010         0.0679                   108.293461
# ...          ...            ...                          ...
# 5727  04-02-2026     66593.2000                    99.995345
# 5728  04-03-2026     66787.9000                   100.292372
# 5729  04-04-2026     67136.0000                   100.521202
# 5730  04-05-2026     69086.7000                   102.905595
# 5731  04-06-2026     68747.8000                    99.509457
#
# [5732 rows x 3 columns]

# %%
oil
# Out:
#             Date   Price
# 0     1987-05-20   18.63
# 1     1987-05-21   18.45
# 2     1987-05-22   18.55
# 3     1987-05-25   18.60
# 4     1987-05-26   18.63
# ...          ...     ...
# 9856  2026-03-24  108.42
# 9857  2026-03-25  109.14
# 9858  2026-03-26  113.39
# 9859  2026-03-27  121.47
# 9860  2026-03-30  121.88
#
# [9861 rows x 2 columns]

# %%
oil["Date"] = pd.to_datetime(oil["Date"], format = "%Y-%M-%d")
oil["Date"] = oil["Date"].dt.strftime("%M-%d-%Y")
oil = oil.rename(columns = {"Price" : "Oil Futures Price"})
oil
# Out:
#             Date  Oil Futures Price
# 0     05-20-1987              18.63
# 1     05-21-1987              18.45
# 2     05-22-1987              18.55
# 3     05-25-1987              18.60
# 4     05-26-1987              18.63
# ...          ...                ...
# 9856  03-24-2026             108.42
# 9857  03-25-2026             109.14
# 9858  03-26-2026             113.39
# 9859  03-27-2026             121.47
# 9860  03-30-2026             121.88
#
# [9861 rows x 2 columns]

# %%
oil["Oil Percent Change Rate"] = (1 + oil["Oil Futures Price"].pct_change()) * 100
oil
# Out:
#             Date  Oil Futures Price  Oil Percent Change Rate
# 0     05-20-1987              18.63                      NaN
# 1     05-21-1987              18.45                99.033816
# 2     05-22-1987              18.55               100.542005
# 3     05-25-1987              18.60               100.269542
# 4     05-26-1987              18.63               100.161290
# ...          ...                ...                      ...
# 9856  03-24-2026             108.42               104.460931
# 9857  03-25-2026             109.14               100.664084
# 9858  03-26-2026             113.39               103.894081
# 9859  03-27-2026             121.47               107.125849
# 9860  03-30-2026             121.88               100.337532
#
# [9861 rows x 3 columns]

# %%
cpi
# Out:
#     observation_date  CPIAUCSL
# 0         1947-01-01    21.480
# 1         1947-02-01    21.620
# 2         1947-03-01    22.000
# 3         1947-04-01    22.000
# 4         1947-05-01    21.950
# ..               ...       ...
# 945       2025-10-01       NaN
# 946       2025-11-01   325.063
# 947       2025-12-01   326.031
# 948       2026-01-01   326.588
# 949       2026-02-01   327.460
#
# [950 rows x 2 columns]

# %%
cpi = cpi.rename(columns = {"observation_date" : "Month", "CPIAUCSL" : "CPI Rate"})
cpi.head()
# Out:
#         Month  CPI Rate
# 0  1947-01-01     21.48
# 1  1947-02-01     21.62
# 2  1947-03-01     22.00
# 3  1947-04-01     22.00
# 4  1947-05-01     21.95

# %%
cpi["Month"] = pd.to_datetime(cpi["Month"], format = "%Y-%M-%d")
cpi["Month"] = cpi["Month"].dt.strftime("%M-%d-%Y")
cpi
#The CPI rate for October 2025 was not calculated due to the government shutdown, so it shows up as not available.
# Out:
#           Month  CPI Rate
# 0    01-01-1947    21.480
# 1    02-01-1947    21.620
# 2    03-01-1947    22.000
# 3    04-01-1947    22.000
# 4    05-01-1947    21.950
# ..          ...       ...
# 945  10-01-2025       NaN
# 946  11-01-2025   325.063
# 947  12-01-2025   326.031
# 948  01-01-2026   326.588
# 949  02-01-2026   327.460
#
# [950 rows x 2 columns]

# %%
cpi["CPI Percent Change Rate"] = (1 + cpi["CPI Rate"].pct_change()) * 100
cpi
# Out:
# /var/folders/_k/hbpmd3cn3cl4dn7css2gnbv80000gp/T/ipykernel_21287/1486660698.py:1: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   cpi["CPI Percent Change Rate"] = (1 + cpi["CPI Rate"].pct_change()) * 100
#           Month  CPI Rate  CPI Percent Change Rate
# 0    01-01-1947    21.480                      NaN
# 1    02-01-1947    21.620               100.651769
# 2    03-01-1947    22.000               101.757632
# 3    04-01-1947    22.000               100.000000
# 4    05-01-1947    21.950                99.772727
# ..          ...       ...                      ...
# 945  10-01-2025       NaN               100.000000
# 946  11-01-2025   325.063               100.252278
# 947  12-01-2025   326.031               100.297788
# 948  01-01-2026   326.588               100.170843
# 949  02-01-2026   327.460               100.267003
#
# [950 rows x 3 columns]

# %%
dow
# Out:
#                                              Unnamed: 0    Unnamed: 1
# 0                                                   NaN           NaN
# 1                                                   NaN           NaN
# 2                                                As of:  Apr 06, 2026
# 3                                                   NaN           NaN
# 4                                                   NaN           NaN
# ...                                                 ...           ...
# 2523                                2026-04-06 00:00:00      46669.88
# 2524                                                NaN           NaN
# 2525                                                NaN           NaN
# 2526                                                NaN           NaN
# 2527  DISCLAIMER\n\nPERFORMANCE DISCLOSURE/BACK-TEST...           NaN
#
# [2528 rows x 2 columns]

# %%
dow = pd.read_excel("Dow Jones Composite.xlsx", skiprows = 6, nrows = 2519, usecols = "A:B")
dow

#Here, I reformatted the dow dataframe to better reflect the data and not be affected by the whitespace in the file
# Out:
#      Effective date   Dow Jones Industrial Average
# 0         2016-03-31                      17685.09
# 1         2016-04-01                      17792.75
# 2         2016-04-04                      17737.00
# 3         2016-04-05                      17603.32
# 4         2016-04-06                      17716.05
# ...              ...                           ...
# 2513      2026-03-30                      45216.14
# 2514      2026-03-31                      46341.51
# 2515      2026-04-01                      46565.74
# 2516      2026-04-02                      46504.67
# 2517      2026-04-06                      46669.88
#
# [2518 rows x 2 columns]

# %%
dow = dow.rename(columns = {"Effective date " : "Date", "Dow Jones Industrial Average" : "Dow Jones Composite Price"})
dow
# Out:
#            Date  Dow Jones Composite Price
# 0    2016-03-31                   17685.09
# 1    2016-04-01                   17792.75
# 2    2016-04-04                   17737.00
# 3    2016-04-05                   17603.32
# 4    2016-04-06                   17716.05
# ...         ...                        ...
# 2513 2026-03-30                   45216.14
# 2514 2026-03-31                   46341.51
# 2515 2026-04-01                   46565.74
# 2516 2026-04-02                   46504.67
# 2517 2026-04-06                   46669.88
#
# [2518 rows x 2 columns]

# %%
dow["Date"] = pd.to_datetime(dow["Date"], format = "%Y-%M-%d")
dow["Date"] = dow["Date"].dt.strftime("%m-%d-%Y")
dow
# Out:
#             Date  Dow Jones Composite Price
# 0     03-31-2016                   17685.09
# 1     04-01-2016                   17792.75
# 2     04-04-2016                   17737.00
# 3     04-05-2016                   17603.32
# 4     04-06-2016                   17716.05
# ...          ...                        ...
# 2513  03-30-2026                   45216.14
# 2514  03-31-2026                   46341.51
# 2515  04-01-2026                   46565.74
# 2516  04-02-2026                   46504.67
# 2517  04-06-2026                   46669.88
#
# [2518 rows x 2 columns]

# %%
dow["DOW Percent Change Rate"] = (1 + dow["Dow Jones Composite Price"].pct_change()) * 100
dow
# Out:
#             Date  Dow Jones Composite Price  DOW Percent Change Rate
# 0     03-31-2016                   17685.09                      NaN
# 1     04-01-2016                   17792.75               100.608761
# 2     04-04-2016                   17737.00                99.686670
# 3     04-05-2016                   17603.32                99.246321
# 4     04-06-2016                   17716.05               100.640391
# ...          ...                        ...                      ...
# 2513  03-30-2026                   45216.14               100.109594
# 2514  03-31-2026                   46341.51               102.488868
# 2515  04-01-2026                   46565.74               100.483864
# 2516  04-02-2026                   46504.67                99.868852
# 2517  04-06-2026                   46669.88               100.355255
#
# [2518 rows x 3 columns]

# %%
eth1
# Out:
#             Date         Open         High          Low        Close  \
# 0     2015-08-08     2.793760     2.798810     0.714725     0.753325
# 1     2015-08-09     0.706136     0.879810     0.629191     0.701897
# 2     2015-08-10     0.713989     0.729854     0.636546     0.708448
# 3     2015-08-11     0.708087     1.131410     0.663235     1.067860
# 4     2015-08-12     1.058750     1.289940     0.883608     1.217440
# ...          ...          ...          ...          ...          ...
# 2115  2021-05-23  2298.367188  2384.411621  1737.468750  2109.579834
# 2116  2021-05-24  2099.936035  2672.595703  2090.639648  2643.591064
# 2117  2021-05-25  2649.033203  2750.534912  2394.355469  2706.628906
# 2118  2021-05-26  2707.052734  2911.735596  2652.094482  2888.698730
# 2119  2021-05-27  2872.692383  2872.692383  2642.607910  2776.133057
#
#         Adj Close        Volume
# 0        0.753325  6.741880e+05
# 1        0.701897  5.321700e+05
# 2        0.708448  4.052830e+05
# 3        1.067860  1.463100e+06
# 4        1.217440  2.150620e+06
# ...           ...           ...
# 2115  2109.579834  5.600572e+10
# 2116  2643.591064  5.369712e+10
# 2117  2706.628906  4.955833e+10
# 2118  2888.698730  4.249977e+10
# 2119  2776.133057  3.456504e+10
#
# [2120 rows x 7 columns]

# %%
eth1 = eth1[["Date", "Close"]]
eth1 = eth1.rename(columns = {"Close" : "Price"})
eth1
# Out:
#             Date        Price
# 0     2015-08-08     0.753325
# 1     2015-08-09     0.701897
# 2     2015-08-10     0.708448
# 3     2015-08-11     1.067860
# 4     2015-08-12     1.217440
# ...          ...          ...
# 2115  2021-05-23  2109.579834
# 2116  2021-05-24  2643.591064
# 2117  2021-05-25  2706.628906
# 2118  2021-05-26  2888.698730
# 2119  2021-05-27  2776.133057
#
# [2120 rows x 2 columns]

# %%
eth1["Date"] = pd.to_datetime(eth1["Date"], format = "%Y-%M-%d")
eth1["Date"] = eth1["Date"].dt.strftime("%m-%d-%Y")
eth1
# Out:
#             Date        Price
# 0     01-08-2015     0.753325
# 1     01-09-2015     0.701897
# 2     01-10-2015     0.708448
# 3     01-11-2015     1.067860
# 4     01-12-2015     1.217440
# ...          ...          ...
# 2115  01-23-2021  2109.579834
# 2116  01-24-2021  2643.591064
# 2117  01-25-2021  2706.628906
# 2118  01-26-2021  2888.698730
# 2119  01-27-2021  2776.133057
#
# [2120 rows x 2 columns]

# %%
eth2
# Out:
#               Date     Price      Open      High       Low      Vol Change %
# 0     May 06, 2023  1,969.82  1,993.33  2,013.10  1,964.43  641.57K   -1.18%
# 1     May 05, 2023  1,993.33  1,877.06  1,996.64  1,875.66  589.05K    6.19%
# 2     May 04, 2023  1,877.06  1,904.76  1,915.15  1,868.18  372.69K   -1.45%
# 3     May 03, 2023  1,904.74  1,869.74  1,915.00  1,844.72  489.66K    1.87%
# 4     May 02, 2023  1,869.74  1,830.75  1,878.70  1,823.25  391.27K    2.13%
# ...            ...       ...       ...       ...       ...      ...      ...
# 2609  Mar 14, 2016      12.5     15.07     15.07      11.4   92.18K  -17.05%
# 2610  Mar 13, 2016     15.07     12.92     15.07     12.92    1.30K   16.64%
# 2611  Mar 12, 2016     12.92     11.95     13.45     11.95    0.83K    8.12%
# 2612  Mar 11, 2016     11.95     11.75     11.95     11.75    0.18K    1.70%
# 2613  Mar 10, 2016     11.75      11.2     11.85     11.07    0.00K    4.91%
#
# [2614 rows x 7 columns]

# %%
eth2 = eth2.iloc[::-1]
eth2 = eth2.reset_index(drop = True)
eth2
# Out:
#               Date     Price      Open      High       Low      Vol Change %
# 0     Mar 10, 2016     11.75      11.2     11.85     11.07    0.00K    4.91%
# 1     Mar 11, 2016     11.95     11.75     11.95     11.75    0.18K    1.70%
# 2     Mar 12, 2016     12.92     11.95     13.45     11.95    0.83K    8.12%
# 3     Mar 13, 2016     15.07     12.92     15.07     12.92    1.30K   16.64%
# 4     Mar 14, 2016      12.5     15.07     15.07      11.4   92.18K  -17.05%
# ...            ...       ...       ...       ...       ...      ...      ...
# 2609  May 02, 2023  1,869.74  1,830.75  1,878.70  1,823.25  391.27K    2.13%
# 2610  May 03, 2023  1,904.74  1,869.74  1,915.00  1,844.72  489.66K    1.87%
# 2611  May 04, 2023  1,877.06  1,904.76  1,915.15  1,868.18  372.69K   -1.45%
# 2612  May 05, 2023  1,993.33  1,877.06  1,996.64  1,875.66  589.05K    6.19%
# 2613  May 06, 2023  1,969.82  1,993.33  2,013.10  1,964.43  641.57K   -1.18%
#
# [2614 rows x 7 columns]

# %%
eth2 = eth2[["Date", "Price"]]
eth2
# Out:
#               Date     Price
# 0     Mar 10, 2016     11.75
# 1     Mar 11, 2016     11.95
# 2     Mar 12, 2016     12.92
# 3     Mar 13, 2016     15.07
# 4     Mar 14, 2016      12.5
# ...            ...       ...
# 2609  May 02, 2023  1,869.74
# 2610  May 03, 2023  1,904.74
# 2611  May 04, 2023  1,877.06
# 2612  May 05, 2023  1,993.33
# 2613  May 06, 2023  1,969.82
#
# [2614 rows x 2 columns]

# %%
eth2["Date"] = pd.to_datetime(eth2["Date"], format = "%b %d, %Y")
eth2["Date"] = eth2["Date"].dt.strftime("%m-%d-%Y")
eth2
# Out:
# /var/folders/_k/hbpmd3cn3cl4dn7css2gnbv80000gp/T/ipykernel_21287/4138373936.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eth2["Date"] = pd.to_datetime(eth2["Date"], format = "%b %d, %Y")
# /var/folders/_k/hbpmd3cn3cl4dn7css2gnbv80000gp/T/ipykernel_21287/4138373936.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eth2["Date"] = eth2["Date"].dt.strftime("%m-%d-%Y")
#             Date     Price
# 0     03-10-2016     11.75
# 1     03-11-2016     11.95
# 2     03-12-2016     12.92
# 3     03-13-2016     15.07
# 4     03-14-2016      12.5
# ...          ...       ...
# 2609  05-02-2023  1,869.74
# 2610  05-03-2023  1,904.74
# 2611  05-04-2023  1,877.06
# 2612  05-05-2023  1,993.33
# 2613  05-06-2023  1,969.82
#
# [2614 rows x 2 columns]

# %%
eth3
# Out:
#        datetime     open     high      low    close        volume
# 0     8/17/2017   301.13   312.18   298.00   302.00    7030.71034
# 1     8/18/2017   302.00   311.79   283.94   293.96    9537.84646
# 2     8/19/2017   293.31   299.90   278.00   290.91    2146.19773
# 3     8/20/2017   289.41   300.53   282.85   299.10    2510.13871
# 4     8/21/2017   299.10   346.52   294.60   323.29    5219.44542
# ...         ...      ...      ...      ...      ...           ...
# 2396   3/9/2024  3883.37  3942.00  3870.01  3905.21  254839.13860
# 2397  3/10/2024  3905.20  3964.67  3791.26  3878.47  356664.68000
# 2398  3/11/2024  3878.47  4086.23  3722.95  4064.80  721554.51390
# 2399  3/12/2024  4064.80  4093.92  3828.98  3979.96  632787.39410
# 2400  3/13/2024  3979.97  4083.00  3932.23  4004.79  482305.77660
#
# [2401 rows x 6 columns]

# %%
eth3 = eth3[["datetime", "close"]]
eth3
# Out:
#        datetime    close
# 0     8/17/2017   302.00
# 1     8/18/2017   293.96
# 2     8/19/2017   290.91
# 3     8/20/2017   299.10
# 4     8/21/2017   323.29
# ...         ...      ...
# 2396   3/9/2024  3905.21
# 2397  3/10/2024  3878.47
# 2398  3/11/2024  4064.80
# 2399  3/12/2024  3979.96
# 2400  3/13/2024  4004.79
#
# [2401 rows x 2 columns]

# %%
eth3 = eth3.rename(columns = {"datetime" : "Date", "close" : "Price"})
eth3
# Out:
#            Date    Price
# 0     8/17/2017   302.00
# 1     8/18/2017   293.96
# 2     8/19/2017   290.91
# 3     8/20/2017   299.10
# 4     8/21/2017   323.29
# ...         ...      ...
# 2396   3/9/2024  3905.21
# 2397  3/10/2024  3878.47
# 2398  3/11/2024  4064.80
# 2399  3/12/2024  3979.96
# 2400  3/13/2024  4004.79
#
# [2401 rows x 2 columns]

# %%
eth3["Date"] = pd.to_datetime(eth3["Date"], format = "%m/%d/%Y")
eth3["Date"] = eth3["Date"].dt.strftime("%m-%d-%Y")
eth3
# Out:
#             Date    Price
# 0     08-17-2017   302.00
# 1     08-18-2017   293.96
# 2     08-19-2017   290.91
# 3     08-20-2017   299.10
# 4     08-21-2017   323.29
# ...          ...      ...
# 2396  03-09-2024  3905.21
# 2397  03-10-2024  3878.47
# 2398  03-11-2024  4064.80
# 2399  03-12-2024  3979.96
# 2400  03-13-2024  4004.79
#
# [2401 rows x 2 columns]

# %%
eth4
# Out:
#             Date  Close/Last  Volume     Open     High      Low
# 0     04/06/2026     2107.81     NaN  2128.73  2119.17  2093.82
# 1     04/05/2026     2128.30     NaN  2056.47  2143.83  2110.33
# 2     04/04/2026     2056.71     NaN  2050.01  2065.51  2054.37
# 3     04/03/2026     2058.10     NaN  2038.58  2074.69  2042.35
# 4     04/02/2026     2052.71     NaN  2056.78  2062.47  2042.35
# ...          ...         ...     ...      ...      ...      ...
# 2298  03/12/2019      133.80     NaN   132.99   134.93   129.14
# 2299  03/11/2019      133.42     NaN   136.10   136.23   131.66
# 2300  03/10/2019      135.72     NaN   137.52   137.75   134.53
# 2301  03/09/2019      137.52     NaN   133.85   138.57   133.38
# 2302  03/08/2019      133.85     NaN   136.93   139.45   131.66
#
# [2303 rows x 6 columns]

# %%
eth4 = eth4.iloc[::-1]
eth4 = eth4.reset_index(drop = True)
eth4
# Out:
#             Date  Close/Last  Volume     Open     High      Low
# 0     03/08/2019      133.85     NaN   136.93   139.45   131.66
# 1     03/09/2019      137.52     NaN   133.85   138.57   133.38
# 2     03/10/2019      135.72     NaN   137.52   137.75   134.53
# 3     03/11/2019      133.42     NaN   136.10   136.23   131.66
# 4     03/12/2019      133.80     NaN   132.99   134.93   129.14
# ...          ...         ...     ...      ...      ...      ...
# 2298  04/02/2026     2052.71     NaN  2056.78  2062.47  2042.35
# 2299  04/03/2026     2058.10     NaN  2038.58  2074.69  2042.35
# 2300  04/04/2026     2056.71     NaN  2050.01  2065.51  2054.37
# 2301  04/05/2026     2128.30     NaN  2056.47  2143.83  2110.33
# 2302  04/06/2026     2107.81     NaN  2128.73  2119.17  2093.82
#
# [2303 rows x 6 columns]

# %%
eth4 = eth4[["Date", "Close/Last"]]
eth4 = eth4.rename(columns = {"Close/Last" : "Price"})
eth4
# Out:
#             Date    Price
# 0     03/08/2019   133.85
# 1     03/09/2019   137.52
# 2     03/10/2019   135.72
# 3     03/11/2019   133.42
# 4     03/12/2019   133.80
# ...          ...      ...
# 2298  04/02/2026  2052.71
# 2299  04/03/2026  2058.10
# 2300  04/04/2026  2056.71
# 2301  04/05/2026  2128.30
# 2302  04/06/2026  2107.81
#
# [2303 rows x 2 columns]

# %%
eth4["Date"] = pd.to_datetime(eth4["Date"], format = "%m/%d/%Y")
eth4["Date"] = eth4["Date"].dt.strftime("%m-%d-%Y")
eth4
# Out:
#             Date    Price
# 0     03-08-2019   133.85
# 1     03-09-2019   137.52
# 2     03-10-2019   135.72
# 3     03-11-2019   133.42
# 4     03-12-2019   133.80
# ...          ...      ...
# 2298  04-02-2026  2052.71
# 2299  04-03-2026  2058.10
# 2300  04-04-2026  2056.71
# 2301  04-05-2026  2128.30
# 2302  04-06-2026  2107.81
#
# [2303 rows x 2 columns]

# %%
eth = pd.concat([eth1, eth2], axis = "rows")
eth.drop_duplicates(subset = "Date", keep = "first")
eth = pd.concat([eth, eth3], axis = "rows")
eth.drop_duplicates(subset = "Date", keep = "first")
eth = pd.concat([eth, eth4], axis = "rows")
eth.drop_duplicates(subset = "Date", keep = "first")
eth = eth.rename(columns = {"Price" : "Ethereum Price"})
eth
# Out:
#             Date Ethereum Price
# 0     01-08-2015       0.753325
# 1     01-09-2015       0.701897
# 2     01-10-2015       0.708448
# 3     01-11-2015        1.06786
# 4     01-12-2015        1.21744
# ...          ...            ...
# 2298  04-02-2026        2052.71
# 2299  04-03-2026         2058.1
# 2300  04-04-2026        2056.71
# 2301  04-05-2026         2128.3
# 2302  04-06-2026        2107.81
#
# [9438 rows x 2 columns]

# %%
eth = eth.sort_values(by = "Date")
#I had to come back here much later to fix the ethereum dataset

# %%
eth = eth.drop_duplicates(subset = "Date", keep = "first")

# %%
eth["Date"] = pd.to_datetime(eth["Date"], format = "%m-%d-%Y")
eth = eth.sort_values(by = "Date")
eth = eth.reset_index(drop = True)
eth
# Out:
#            Date Ethereum Price
# 0    2015-01-01       0.690215
# 1    2015-01-02       0.989789
# 2    2015-01-03       0.687171
# 3    2015-01-04       0.840041
# 4    2015-01-05       0.862438
# ...         ...            ...
# 3733 2026-04-02        2052.71
# 3734 2026-04-03         2058.1
# 3735 2026-04-04        2056.71
# 3736 2026-04-05         2128.3
# 3737 2026-04-06        2107.81
#
# [3738 rows x 2 columns]

# %%
eth["Date"] = pd.to_datetime(eth["Date"], format = "%Y-%m-%d")
eth["Date"] = eth["Date"].dt.strftime("%m-%d-%Y")
eth
# Out:
#             Date Ethereum Price
# 0     01-01-2015       0.690215
# 1     01-02-2015       0.989789
# 2     01-03-2015       0.687171
# 3     01-04-2015       0.840041
# 4     01-05-2015       0.862438
# ...          ...            ...
# 3733  04-02-2026        2052.71
# 3734  04-03-2026         2058.1
# 3735  04-04-2026        2056.71
# 3736  04-05-2026         2128.3
# 3737  04-06-2026        2107.81
#
# [3738 rows x 2 columns]

# %%
eth["Ethereum Price"] = eth["Ethereum Price"].replace(",","")
eth["Ethereum Price"] = pd.to_numeric(eth["Ethereum Price"], errors = "coerce")
#I kept getting an error message, so I cut my losses and coerced all the errors to get this part doen with.

# %%
eth["Ethereum Percent Change Rate"] = (1 + eth["Ethereum Price"].pct_change()) * 100
eth
# Out:
# /var/folders/_k/hbpmd3cn3cl4dn7css2gnbv80000gp/T/ipykernel_21287/2512837222.py:1: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   eth["Ethereum Percent Change Rate"] = (1 + eth["Ethereum Price"].pct_change()) * 100
#             Date  Ethereum Price  Ethereum Percent Change Rate
# 0     01-01-2015        0.690215                           NaN
# 1     01-02-2015        0.989789                    143.402998
# 2     01-03-2015        0.687171                     69.426009
# 3     01-04-2015        0.840041                    122.246282
# 4     01-05-2015        0.862438                    102.666179
# ...          ...             ...                           ...
# 3733  04-02-2026     2052.710000                     99.844837
# 3734  04-03-2026     2058.100000                    100.262580
# 3735  04-04-2026     2056.710000                     99.932462
# 3736  04-05-2026     2128.300000                    103.480802
# 3737  04-06-2026     2107.810000                     99.037260
#
# [3738 rows x 3 columns]

# %%
gold
# Out:
#             Date   Price    Open    High     Low  Volume  Chg%
# 0     2026-01-02  135793  136143  137037  135525   51877  0.02
# 1     2026-01-01  135771  135687  135850  135001   14622  0.23
# 2     2025-12-31  135454  136526  136527  134866   59050  1.10
# 3     2025-12-30  133974  133185  134880  132853   36733  1.04
# 4     2025-12-29  132595  137628  138269  131695   90640 -3.77
# ...          ...     ...     ...     ...     ...     ...   ...
# 3099  2014-01-06   29119   29300   29395   29051   24380 -0.55
# 3100  2014-01-04   29279   29279   29279   29279       0 -1.51
# 3101  2014-01-03   29727   30031   30125   29539    3050 -0.83
# 3102  2014-01-02   29975   29678   30050   29678    3140  1.47
# 3103  2014-01-01   29542   29435   29598   29340    2930  0.25
#
# [3104 rows x 7 columns]

# %%
gold = gold[["Date", "Price"]]
gold = gold.iloc[::-1]
gold = gold.reset_index(drop = True)
gold
# Out:
#             Date   Price
# 0     2014-01-01   29542
# 1     2014-01-02   29975
# 2     2014-01-03   29727
# 3     2014-01-04   29279
# 4     2014-01-06   29119
# ...          ...     ...
# 3099  2025-12-29  132595
# 3100  2025-12-30  133974
# 3101  2025-12-31  135454
# 3102  2026-01-01  135771
# 3103  2026-01-02  135793
#
# [3104 rows x 2 columns]

# %%
gold["Date"] = pd.to_datetime(gold["Date"], format = "%Y-%m-%d")
gold["Date"] = gold["Date"].dt.strftime("%m-%d-%Y")
gold = gold.rename(columns = {"Price" : "Gold Price"})
gold
# Out:
#             Date  Gold Price
# 0     01-01-2014       29542
# 1     01-02-2014       29975
# 2     01-03-2014       29727
# 3     01-04-2014       29279
# 4     01-06-2014       29119
# ...          ...         ...
# 3099  12-29-2025      132595
# 3100  12-30-2025      133974
# 3101  12-31-2025      135454
# 3102  01-01-2026      135771
# 3103  01-02-2026      135793
#
# [3104 rows x 2 columns]

# %%
gold["Gold Percent Change Rate"] = (1 + gold["Gold Price"].pct_change()) * 100
gold
# Out:
#             Date  Gold Price  Gold Percent Change Rate
# 0     01-01-2014       29542                       NaN
# 1     01-02-2014       29975                101.465710
# 2     01-03-2014       29727                 99.172644
# 3     01-04-2014       29279                 98.492953
# 4     01-06-2014       29119                 99.453533
# ...          ...         ...                       ...
# 3099  12-29-2025      132595                 96.230468
# 3100  12-30-2025      133974                101.040009
# 3101  12-31-2025      135454                101.104692
# 3102  01-01-2026      135771                100.234028
# 3103  01-02-2026      135793                100.016204
#
# [3104 rows x 3 columns]

# %%
appl
# Out:
#             Date Close/Last     Volume      Open      High       Low
# 0     04/06/2026    $258.86   29329910   $256.51   $262.16   $256.46
# 1     04/02/2026    $255.92   31289370   $254.20   $256.13   $250.65
# 2     04/01/2026    $255.63   40059430   $254.08   $256.18   $253.33
# 3     03/31/2026    $253.79   49598090   $247.91   $255.48  $247.101
# 4     03/30/2026    $246.63   39446210   $250.07   $250.87   $245.51
# ...          ...        ...        ...       ...       ...       ...
# 2508  04/13/2016     $28.01  131087040    $27.70   $28.085    $27.70
# 2509  04/12/2016     $27.61  108602280   $27.335   $27.625   $27.165
# 2510  04/11/2016    $27.255  117431760  $27.2425  $27.6525  $27.2075
# 2511  04/08/2016    $27.165   94215160  $27.2275  $27.4425  $27.0425
# 2512  04/07/2016    $27.135  126943240  $27.4875   $27.605  $27.0302
#
# [2513 rows x 6 columns]

# %%
appl = appl[["Date", "Close/Last"]]
appl.head()
# Out:
#          Date Close/Last
# 0  04/06/2026    $258.86
# 1  04/02/2026    $255.92
# 2  04/01/2026    $255.63
# 3  03/31/2026    $253.79
# 4  03/30/2026    $246.63

# %%
appl["Close/Last"] = appl["Close/Last"].str.replace("$", "")
appl = appl.iloc[::-1]
appl = appl.reset_index(drop = True)
appl = appl.rename(columns = {"Close/Last" : "APPL Price"})
appl["Date"] = pd.to_datetime(appl["Date"], format = "%m/%d/%Y")
appl["Date"] = appl["Date"].dt.strftime("%m-%d-%Y")
appl
# Out:
# /var/folders/_k/hbpmd3cn3cl4dn7css2gnbv80000gp/T/ipykernel_21287/2047404091.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   appl["Close/Last"] = appl["Close/Last"].str.replace("$", "")
#             Date APPL Price
# 0     04-07-2016     27.135
# 1     04-08-2016     27.165
# 2     04-11-2016     27.255
# 3     04-12-2016      27.61
# 4     04-13-2016      28.01
# ...          ...        ...
# 2508  03-30-2026     246.63
# 2509  03-31-2026     253.79
# 2510  04-01-2026     255.63
# 2511  04-02-2026     255.92
# 2512  04-06-2026     258.86
#
# [2513 rows x 2 columns]

# %%
appl["APPL Price"] = appl["APPL Price"].replace(",","")
appl["APPL Price"] = pd.to_numeric(appl["APPL Price"], errors = "coerce")

# %%
appl["APPL Percent Change Rate"] = (1 + appl["APPL Price"].pct_change()) * 100
appl
# Out:
#             Date  APPL Price  APPL Percent Change Rate
# 0     04-07-2016      27.135                       NaN
# 1     04-08-2016      27.165                100.110558
# 2     04-11-2016      27.255                100.331309
# 3     04-12-2016      27.610                101.302513
# 4     04-13-2016      28.010                101.448750
# ...          ...         ...                       ...
# 2508  03-30-2026     246.630                 99.127814
# 2509  03-31-2026     253.790                102.903134
# 2510  04-01-2026     255.630                100.725009
# 2511  04-02-2026     255.920                100.113445
# 2512  04-06-2026     258.860                101.148796
#
# [2513 rows x 3 columns]

# %%
amzn = amzn[["Date", "Close/Last"]]
amzn["Close/Last"] = amzn["Close/Last"].str.replace("$", "")
amzn = amzn.iloc[::-1]
amzn = amzn.reset_index(drop = True)
amzn = amzn.rename(columns = {"Close/Last" : "AMZN Price"})
amzn["Date"] = pd.to_datetime(amzn["Date"], format = "%m/%d/%Y")
amzn["Date"] = amzn["Date"].dt.strftime("%m-%d-%Y")
amzn
# Out:
#             Date AMZN Price
# 0     04-07-2016    29.5715
# 1     04-08-2016      29.73
# 2     04-11-2016    29.7965
# 3     04-12-2016    30.1585
# 4     04-13-2016     30.741
# ...          ...        ...
# 2508  03-30-2026     200.95
# 2509  03-31-2026     208.27
# 2510  04-01-2026     210.57
# 2511  04-02-2026     209.77
# 2512  04-06-2026     212.79
#
# [2513 rows x 2 columns]

# %%
amzn["AMZN Price"] = amzn["AMZN Price"].replace(",","")
amzn["AMZN Price"] = pd.to_numeric(amzn["AMZN Price"], errors = "coerce")
amzn["AMZN Percent Change Rate"] = (1 + amzn["AMZN Price"].pct_change()) * 100
amzn
# Out:
#             Date  AMZN Price  AMZN Percent Change Rate
# 0     04-07-2016     29.5715                       NaN
# 1     04-08-2016     29.7300                100.535989
# 2     04-11-2016     29.7965                100.223680
# 3     04-12-2016     30.1585                101.214908
# 4     04-13-2016     30.7410                101.931462
# ...          ...         ...                       ...
# 2508  03-30-2026    200.9500                100.807665
# 2509  03-31-2026    208.2700                103.642697
# 2510  04-01-2026    210.5700                101.104336
# 2511  04-02-2026    209.7700                 99.620079
# 2512  04-06-2026    212.7900                101.439672
#
# [2513 rows x 3 columns]

# %%
comp = comp[["Date", "Close/Last"]]
#comp["Close/Last"] = comp["Close/Last"].str.replace("$", "")
comp = comp.iloc[::-1]
comp = comp.reset_index(drop = True)
comp = comp.rename(columns = {"Close/Last" : "NASDAQ Composite Price"})
comp["Date"] = pd.to_datetime(comp["Date"], format = "%m/%d/%Y")
comp["Date"] = comp["Date"].dt.strftime("%m-%d-%Y")
comp
# Out:
#             Date  NASDAQ Composite Price
# 0     04-07-2016                 4848.37
# 1     04-08-2016                 4850.69
# 2     04-11-2016                 4833.40
# 3     04-12-2016                 4872.09
# 4     04-13-2016                 4947.42
# ...          ...                     ...
# 2508  03-30-2026                20794.64
# 2509  03-31-2026                21590.63
# 2510  04-01-2026                21840.95
# 2511  04-02-2026                21879.18
# 2512  04-06-2026                21996.34
#
# [2513 rows x 2 columns]

# %%
comp["NASDAQ Composite Price"] = comp["NASDAQ Composite Price"].replace(",","")
comp["NASDAQ Composite Price"] = pd.to_numeric(comp["NASDAQ Composite Price"], errors = "coerce")
comp["NASDAQ Composite Percent Change Rate"] = (1 + comp["NASDAQ Composite Price"].pct_change()) * 100
comp
# Out:
#             Date  NASDAQ Composite Price  NASDAQ Composite Percent Change Rate
# 0     04-07-2016                 4848.37                                   NaN
# 1     04-08-2016                 4850.69                            100.047851
# 2     04-11-2016                 4833.40                             99.643556
# 3     04-12-2016                 4872.09                            100.800472
# 4     04-13-2016                 4947.42                            101.546154
# ...          ...                     ...                                   ...
# 2508  03-30-2026                20794.64                             99.266196
# 2509  03-31-2026                21590.63                            103.827861
# 2510  04-01-2026                21840.95                            101.159392
# 2511  04-02-2026                21879.18                            100.175038
# 2512  04-06-2026                21996.34                            100.535486
#
# [2513 rows x 3 columns]

# %%
googl = googl[["Date", "Close/Last"]]
googl["Close/Last"] = googl["Close/Last"].str.replace("$", "")
googl = googl.iloc[::-1]
googl = googl.reset_index(drop = True)
googl = googl.rename(columns = {"Close/Last" : "GOOGL Price"})
googl["Date"] = pd.to_datetime(googl["Date"], format = "%m/%d/%Y")
googl["Date"] = googl["Date"].dt.strftime("%m-%d-%Y")
googl
# Out:
#             Date GOOGL Price
# 0     04-07-2016      38.006
# 1     04-08-2016     37.9735
# 2     04-11-2016      37.877
# 3     04-12-2016      38.216
# 4     04-13-2016     38.5955
# ...          ...         ...
# 2508  03-30-2026      273.50
# 2509  03-31-2026      287.56
# 2510  04-01-2026      297.39
# 2511  04-02-2026      295.77
# 2512  04-06-2026      299.99
#
# [2513 rows x 2 columns]

# %%
googl["GOOGL Price"] = googl["GOOGL Price"].replace(",","")
googl["GOOGL Price"] = pd.to_numeric(googl["GOOGL Price"], errors = "coerce")
googl["GOOGL Percent Change Rate"] = (1 + googl["GOOGL Price"].pct_change()) * 100
googl
# Out:
#             Date  GOOGL Price  GOOGL Percent Change Rate
# 0     04-07-2016      38.0060                        NaN
# 1     04-08-2016      37.9735                  99.914487
# 2     04-11-2016      37.8770                  99.745875
# 3     04-12-2016      38.2160                 100.895002
# 4     04-13-2016      38.5955                 100.993040
# ...          ...          ...                        ...
# 2508  03-30-2026     273.5000                  99.693811
# 2509  03-31-2026     287.5600                 105.140768
# 2510  04-01-2026     297.3900                 103.418417
# 2511  04-02-2026     295.7700                  99.455261
# 2512  04-06-2026     299.9900                 101.426784
#
# [2513 rows x 3 columns]

# %%
meta = meta[["Date", "Close/Last"]]
meta["Close/Last"] = meta["Close/Last"].str.replace("$", "")
meta = meta.iloc[::-1]
meta = meta.reset_index(drop = True)
meta = meta.rename(columns = {"Close/Last" : "META Price"})
meta["Date"] = pd.to_datetime(meta["Date"], format = "%m/%d/%Y")
meta["Date"] = meta["Date"].dt.strftime("%m-%d-%Y")
meta
# Out:
#             Date META Price
# 0     04-07-2016     113.64
# 1     04-08-2016     110.63
# 2     04-11-2016     108.99
# 3     04-12-2016     110.61
# 4     04-13-2016     110.51
# ...          ...        ...
# 2508  03-30-2026     536.38
# 2509  03-31-2026     572.13
# 2510  04-01-2026     579.23
# 2511  04-02-2026     574.46
# 2512  04-06-2026     573.02
#
# [2513 rows x 2 columns]

# %%
meta["META Price"] = meta["META Price"].replace(",","")
meta["META Price"] = pd.to_numeric(meta["META Price"], errors = "coerce")
meta["META Percent Change Rate"] = (1 + meta["META Price"].pct_change()) * 100
meta
# Out:
#             Date  META Price  META Percent Change Rate
# 0     04-07-2016      113.64                       NaN
# 1     04-08-2016      110.63                 97.351285
# 2     04-11-2016      108.99                 98.517581
# 3     04-12-2016      110.61                101.486375
# 4     04-13-2016      110.51                 99.909592
# ...          ...         ...                       ...
# 2508  03-30-2026      536.38                102.027695
# 2509  03-31-2026      572.13                106.665051
# 2510  04-01-2026      579.23                101.240977
# 2511  04-02-2026      574.46                 99.176493
# 2512  04-06-2026      573.02                 99.749330
#
# [2513 rows x 3 columns]

# %%
msft = msft[["Date", "Close/Last"]]
msft["Close/Last"] = msft["Close/Last"].str.replace("$", "")
msft = msft.iloc[::-1]
msft = msft.reset_index(drop = True)
msft = msft.rename(columns = {"Close/Last" : "MSFT Price"})
msft["Date"] = pd.to_datetime(msft["Date"], format = "%m/%d/%Y")
msft["Date"] = msft["Date"].dt.strftime("%m-%d-%Y")
msft
# Out:
#             Date MSFT Price
# 0     04-07-2016      54.46
# 1     04-08-2016      54.42
# 2     04-11-2016      54.31
# 3     04-12-2016      54.65
# 4     04-13-2016      55.35
# ...          ...        ...
# 2508  03-30-2026     358.96
# 2509  03-31-2026     370.17
# 2510  04-01-2026     369.37
# 2511  04-02-2026     373.46
# 2512  04-06-2026     372.88
#
# [2513 rows x 2 columns]

# %%
msft["MSFT Price"] = msft["MSFT Price"].replace(",","")
msft["MSFT Price"] = pd.to_numeric(msft["MSFT Price"], errors = "coerce")
msft["MSFT Percent Change Rate"] = (1 + msft["MSFT Price"].pct_change()) * 100
msft
# Out:
#             Date  MSFT Price  MSFT Percent Change Rate
# 0     04-07-2016       54.46                       NaN
# 1     04-08-2016       54.42                 99.926552
# 2     04-11-2016       54.31                 99.797868
# 3     04-12-2016       54.65                100.626036
# 4     04-13-2016       55.35                101.280878
# ...          ...         ...                       ...
# 2508  03-30-2026      358.96                100.613841
# 2509  03-31-2026      370.17                103.122911
# 2510  04-01-2026      369.37                 99.783883
# 2511  04-02-2026      373.46                101.107291
# 2512  04-06-2026      372.88                 99.844696
#
# [2513 rows x 3 columns]

# %%
nvda = nvda[["Date", "Close/Last"]]
nvda["Close/Last"] = nvda["Close/Last"].str.replace("$", "")
nvda = nvda.iloc[::-1]
nvda = nvda.reset_index(drop = True)
nvda = nvda.rename(columns = {"Close/Last" : "NVDA Price"})
nvda["Date"] = pd.to_datetime(nvda["Date"], format = "%m/%d/%Y")
nvda["Date"] = nvda["Date"].dt.strftime("%m-%d-%Y")
nvda
# Out:
#             Date NVDA Price
# 0     04-07-2016     0.8858
# 1     04-08-2016     0.8915
# 2     04-11-2016      0.897
# 3     04-12-2016      0.896
# 4     04-13-2016     0.9185
# ...          ...        ...
# 2508  03-30-2026     165.17
# 2509  03-31-2026     174.40
# 2510  04-01-2026     175.75
# 2511  04-02-2026     177.39
# 2512  04-06-2026     177.64
#
# [2513 rows x 2 columns]

# %%
nvda["NVDA Price"] = nvda["NVDA Price"].replace(",","")
nvda["NVDA Price"] = pd.to_numeric(nvda["NVDA Price"], errors = "coerce")
nvda["NVDA Percent Change Rate"] = (1 + nvda["NVDA Price"].pct_change()) * 100
nvda
# Out:
#             Date  NVDA Price  NVDA Percent Change Rate
# 0     04-07-2016      0.8858                       NaN
# 1     04-08-2016      0.8915                100.643486
# 2     04-11-2016      0.8970                100.616938
# 3     04-12-2016      0.8960                 99.888517
# 4     04-13-2016      0.9185                102.511161
# ...          ...         ...                       ...
# 2508  03-30-2026    165.1700                 98.597182
# 2509  03-31-2026    174.4000                105.588182
# 2510  04-01-2026    175.7500                100.774083
# 2511  04-02-2026    177.3900                100.933144
# 2512  04-06-2026    177.6400                100.140932
#
# [2513 rows x 3 columns]

# %%
tsla = tsla[["Date", "Close/Last"]]
tsla["Close/Last"] = tsla["Close/Last"].str.replace("$", "")
tsla = tsla.iloc[::-1]
tsla = tsla.reset_index(drop = True)
tsla = tsla.rename(columns = {"Close/Last" : "TSLA Price"})
tsla["Date"] = pd.to_datetime(tsla["Date"], format = "%m/%d/%Y")
tsla["Date"] = tsla["Date"].dt.strftime("%m-%d-%Y")
tsla
# Out:
#             Date TSLA Price
# 0     04-07-2016    17.1467
# 1     04-08-2016    16.6713
# 2     04-11-2016    16.6613
# 3     04-12-2016    16.5213
# 4     04-13-2016    16.9687
# ...          ...        ...
# 2508  03-30-2026     355.28
# 2509  03-31-2026     371.75
# 2510  04-01-2026     381.26
# 2511  04-02-2026     360.59
# 2512  04-06-2026     352.82
#
# [2513 rows x 2 columns]

# %%
tsla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2513 entries, 0 to 2512
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        2513 non-null   object
#  1   TSLA Price  2513 non-null   object
# dtypes: object(2)
# memory usage: 39.4+ KB

# %%
#tsla["TLSA Price"] = tsla["TSLA Price"].replace(",","")
#tsla["TLSA Price"] = pd.to_numeric(tsla["TSLA Price"], errors = "coerce")
#tsla["Percent Change"] = tsla["TSLA Price"].fillna("0")
tsla["TSLA Percent Change Rate"] = (1 + tsla["TSLA Price"].astype(float).pct_change()) * 100
tsla
# Out:
#             Date TSLA Price  TSLA Percent Change Rate
# 0     04-07-2016    17.1467                       NaN
# 1     04-08-2016    16.6713                 97.227455
# 2     04-11-2016    16.6613                 99.940017
# 3     04-12-2016    16.5213                 99.159729
# 4     04-13-2016    16.9687                102.708019
# ...          ...        ...                       ...
# 2508  03-30-2026     355.28                 98.189758
# 2509  03-31-2026     371.75                104.635780
# 2510  04-01-2026     381.26                102.558171
# 2511  04-02-2026     360.59                 94.578503
# 2512  04-06-2026     352.82                 97.845198
#
# [2513 rows x 3 columns]

# %%
spcomp1 = pd.read_excel("S&P Composite.xlsx", skiprows = 6, nrows = 2519, usecols = "A:B")
spcomp1
# Out:
#      Effective date   S&P 500
# 0         2016-03-31  2059.74
# 1         2016-04-01  2072.78
# 2         2016-04-04  2066.13
# 3         2016-04-05  2045.17
# 4         2016-04-06  2066.66
# ...              ...      ...
# 2513      2026-03-30  6343.72
# 2514      2026-03-31  6528.52
# 2515      2026-04-01  6575.32
# 2516      2026-04-02  6582.69
# 2517      2026-04-06  6611.83
#
# [2518 rows x 2 columns]

# %%
spcomp1 = spcomp1.rename(columns = {"Effective date " : "Date", "S&P 500" : "S&P 500 Composite Price"})
spcomp1
# Out:
#            Date  S&P 500 Composite Price
# 0    2016-03-31                  2059.74
# 1    2016-04-01                  2072.78
# 2    2016-04-04                  2066.13
# 3    2016-04-05                  2045.17
# 4    2016-04-06                  2066.66
# ...         ...                      ...
# 2513 2026-03-30                  6343.72
# 2514 2026-03-31                  6528.52
# 2515 2026-04-01                  6575.32
# 2516 2026-04-02                  6582.69
# 2517 2026-04-06                  6611.83
#
# [2518 rows x 2 columns]

# %%
spcomp1["Date"] = pd.to_datetime(spcomp1["Date"], format = "%Y-%m-%d")
spcomp1["Date"] = spcomp1["Date"].dt.strftime("%m-%d-%Y")
spcomp1
# Out:
#             Date  S&P 500 Composite Price
# 0     03-31-2016                  2059.74
# 1     04-01-2016                  2072.78
# 2     04-04-2016                  2066.13
# 3     04-05-2016                  2045.17
# 4     04-06-2016                  2066.66
# ...          ...                      ...
# 2513  03-30-2026                  6343.72
# 2514  03-31-2026                  6528.52
# 2515  04-01-2026                  6575.32
# 2516  04-02-2026                  6582.69
# 2517  04-06-2026                  6611.83
#
# [2518 rows x 2 columns]

# %%
spcomp1["S&P 500 Composite Percent Change Rate"] = ( 1 + spcomp1["S&P 500 Composite Price"].pct_change()) * 100
spcomp1
# Out:
#             Date  S&P 500 Composite Price  \
# 0     03-31-2016                  2059.74
# 1     04-01-2016                  2072.78
# 2     04-04-2016                  2066.13
# 3     04-05-2016                  2045.17
# 4     04-06-2016                  2066.66
# ...          ...                      ...
# 2513  03-30-2026                  6343.72
# 2514  03-31-2026                  6528.52
# 2515  04-01-2026                  6575.32
# 2516  04-02-2026                  6582.69
# 2517  04-06-2026                  6611.83
#
#       S&P 500 Composite Percent Change Rate
# 0                                       NaN
# 1                                100.633090
# 2                                 99.679175
# 3                                 98.985543
# 4                                101.050768
# ...                                     ...
# 2513                              99.605423
# 2514                             102.913117
# 2515                             100.716855
# 2516                             100.112086
# 2517                             100.442676
#
# [2518 rows x 3 columns]

# %%
spcomp2
# Out:
#             Date   S&P500
# 0     12/22/2014  2078.54
# 1     12/23/2014  2082.17
# 2     12/24/2014  2081.88
# 3     12/26/2014  2088.77
# 4     12/29/2014  2090.57
# ...          ...      ...
# 2512  12/16/2024  6074.08
# 2513  12/17/2024  6050.61
# 2514  12/18/2024  5872.16
# 2515  12/19/2024  5867.08
# 2516  12/20/2024  5930.85
#
# [2517 rows x 2 columns]

# %%
spcomp2["Date"] = pd.to_datetime(spcomp2["Date"], format = "%m/%d/%Y")
spcomp2["Date"] = spcomp2["Date"].dt.strftime("%m-%d-%Y")
spcomp2 = spcomp2.rename(columns = {"S&P500" : "S&P Composite Price"})
spcomp2
#I probably will not use this one
# Out:
#             Date  S&P Composite Price
# 0     12-22-2014              2078.54
# 1     12-23-2014              2082.17
# 2     12-24-2014              2081.88
# 3     12-26-2014              2088.77
# 4     12-29-2014              2090.57
# ...          ...                  ...
# 2512  12-16-2024              6074.08
# 2513  12-17-2024              6050.61
# 2514  12-18-2024              5872.16
# 2515  12-19-2024              5867.08
# 2516  12-20-2024              5930.85
#
# [2517 rows x 2 columns]

# %%
spgold
# Out:
#             Date     Open     High      Low    Close
# 0       4/2/2026  2724.56  2724.56  2724.56  2724.56
# 1       4/1/2026  2802.22  2802.22  2802.22  2802.22
# 2      3/31/2026  2723.92  2723.92  2723.92  2723.92
# 3      3/30/2026  2653.41  2653.41  2653.41  2653.41
# 4      3/27/2026  2634.08  2634.08  2634.08  2634.08
# ...          ...      ...      ...      ...      ...
# 4332    1/7/2009   490.04   490.04   490.04   490.04
# 4333    1/6/2009   504.19   504.19   504.19   504.19
# 4334    1/5/2009   499.42   499.42   499.42   499.42
# 4335    1/2/2009   512.05   512.05   512.05   512.05
# 4336  12/31/2008   514.85   514.85   514.85   514.85
#
# [4337 rows x 5 columns]

# %%
spgold = spgold[["Date", " Close"]]
spgold = spgold.rename(columns = {" Close" : "S&P Gold Price"})
spgold
# Out:
#             Date  S&P Gold Price
# 0       4/2/2026         2724.56
# 1       4/1/2026         2802.22
# 2      3/31/2026         2723.92
# 3      3/30/2026         2653.41
# 4      3/27/2026         2634.08
# ...          ...             ...
# 4332    1/7/2009          490.04
# 4333    1/6/2009          504.19
# 4334    1/5/2009          499.42
# 4335    1/2/2009          512.05
# 4336  12/31/2008          514.85
#
# [4337 rows x 2 columns]

# %%
spgold["Date"] = pd.to_datetime(spgold["Date"], format = "%m/%d/%Y")
spgold["Date"] = spgold["Date"].dt.strftime("%m-%d-%Y")
spgold = spgold.iloc[::-1]
spgold = spgold.reset_index(drop = True)
spgold
# Out:
#             Date  S&P Gold Price
# 0     12-31-2008          514.85
# 1     01-02-2009          512.05
# 2     01-05-2009          499.42
# 3     01-06-2009          504.19
# 4     01-07-2009          490.04
# ...          ...             ...
# 4332  03-27-2026         2634.08
# 4333  03-30-2026         2653.41
# 4334  03-31-2026         2723.92
# 4335  04-01-2026         2802.22
# 4336  04-02-2026         2724.56
#
# [4337 rows x 2 columns]

# %%
spgold["S&P Gold Percent Change Rate"] = (1 + spgold["S&P Gold Price"].pct_change()) * 100
spgold
# Out:
#             Date  S&P Gold Price  S&P Gold Percent Change Rate
# 0     12-31-2008          514.85                           NaN
# 1     01-02-2009          512.05                     99.456152
# 2     01-05-2009          499.42                     97.533444
# 3     01-06-2009          504.19                    100.955108
# 4     01-07-2009          490.04                     97.193518
# ...          ...             ...                           ...
# 4332  03-27-2026         2634.08                    102.615166
# 4333  03-30-2026         2653.41                    100.733843
# 4334  03-31-2026         2723.92                    102.657335
# 4335  04-01-2026         2802.22                    102.874534
# 4336  04-02-2026         2724.56                     97.228626
#
# [4337 rows x 3 columns]

# %%
silver1
# Out:
#                            Date       Open       High        Low      Close  \
# 0     2000-08-30 00:00:00-04:00   4.950000   4.950000   4.895000   4.930000
# 1     2000-08-31 00:00:00-04:00   4.920000   5.045000   4.920000   5.003000
# 2     2000-09-01 00:00:00-04:00   5.035000   5.035000   4.985000   5.004000
# 3     2000-09-05 00:00:00-04:00   4.990000   5.005000   4.975000   4.998000
# 4     2000-09-06 00:00:00-04:00   5.000000   5.000000   4.980000   4.983000
# ...                         ...        ...        ...        ...        ...
# 6355  2025-12-24 00:00:00-05:00  71.514999  71.514999  71.000000  71.030998
# 6356  2025-12-26 00:00:00-05:00  74.500000  78.839996  73.735001  76.486000
# 6357  2025-12-29 00:00:00-05:00  79.699997  79.699997  69.856003  69.856003
# 6358  2025-12-30 00:00:00-05:00  71.330002  77.410004  70.500000  77.374001
# 6359  2025-12-31 00:00:00-05:00  76.065002  76.275002  70.224998  71.139999
#
#       Volume ticker                   name
# 0       2319   SI=F  Silver Futures (SI=F)
# 1       1612   SI=F  Silver Futures (SI=F)
# 2       1375   SI=F  Silver Futures (SI=F)
# 3        856   SI=F  Silver Futures (SI=F)
# 4        232   SI=F  Silver Futures (SI=F)
# ...      ...    ...                    ...
# 6355      35   SI=F  Silver Futures (SI=F)
# 6356     140   SI=F  Silver Futures (SI=F)
# 6357    1608   SI=F  Silver Futures (SI=F)
# 6358    1608   SI=F  Silver Futures (SI=F)
# 6359  110555   SI=F  Silver Futures (SI=F)
#
# [6360 rows x 8 columns]

# %%
silver1 = silver1[["Date", "Close"]]
silver1 = silver1.rename(columns = {"Close" : "Price"})
silver1
# Out:
#                            Date      Price
# 0     2000-08-30 00:00:00-04:00   4.930000
# 1     2000-08-31 00:00:00-04:00   5.003000
# 2     2000-09-01 00:00:00-04:00   5.004000
# 3     2000-09-05 00:00:00-04:00   4.998000
# 4     2000-09-06 00:00:00-04:00   4.983000
# ...                         ...        ...
# 6355  2025-12-24 00:00:00-05:00  71.030998
# 6356  2025-12-26 00:00:00-05:00  76.486000
# 6357  2025-12-29 00:00:00-05:00  69.856003
# 6358  2025-12-30 00:00:00-05:00  77.374001
# 6359  2025-12-31 00:00:00-05:00  71.139999
#
# [6360 rows x 2 columns]

# %%
silver1["Date"] = silver1["Date"].str.slice(stop = 19)
silver1
# Out:
#                      Date      Price
# 0     2000-08-30 00:00:00   4.930000
# 1     2000-08-31 00:00:00   5.003000
# 2     2000-09-01 00:00:00   5.004000
# 3     2000-09-05 00:00:00   4.998000
# 4     2000-09-06 00:00:00   4.983000
# ...                   ...        ...
# 6355  2025-12-24 00:00:00  71.030998
# 6356  2025-12-26 00:00:00  76.486000
# 6357  2025-12-29 00:00:00  69.856003
# 6358  2025-12-30 00:00:00  77.374001
# 6359  2025-12-31 00:00:00  71.139999
#
# [6360 rows x 2 columns]

# %%
silver1["Date"] = pd.to_datetime(silver1["Date"], format = "%Y-%m-%d %H:%M:%S")
silver1["Date"] = silver1["Date"].dt.strftime("%m-%d-%Y")
silver1
# Out:
#             Date      Price
# 0     08-30-2000   4.930000
# 1     08-31-2000   5.003000
# 2     09-01-2000   5.004000
# 3     09-05-2000   4.998000
# 4     09-06-2000   4.983000
# ...          ...        ...
# 6355  12-24-2025  71.030998
# 6356  12-26-2025  76.486000
# 6357  12-29-2025  69.856003
# 6358  12-30-2025  77.374001
# 6359  12-31-2025  71.139999
#
# [6360 rows x 2 columns]

# %%
silver2
# Out:
#            Date    Open    High     Low   Close
# 0    04/06/2026  72.720  73.735  71.335  72.847
# 1    04/02/2026  75.150  75.985  69.610  72.924
# 2    04/01/2026  75.480  76.265  74.000  76.078
# 3    03/31/2026  70.245  75.625  69.100  74.919
# 4    03/30/2026  69.350  72.025  67.700  70.569
# ..          ...     ...     ...     ...     ...
# 249  04/11/2025  31.115  32.210  30.865  31.910
# 250  04/10/2025  30.990  31.245  30.510  30.759
# 251  04/09/2025  29.780  31.065  29.255  30.415
# 252  04/08/2025  30.090  30.520  29.560  29.686
# 253  04/07/2025  29.230  30.760  27.520  29.604
#
# [254 rows x 5 columns]

# %%
silver2 = silver2[["Date", "Close"]]
silver2 = silver2.rename(columns = {"Close" : "Price"})
silver2
# Out:
#            Date   Price
# 0    04/06/2026  72.847
# 1    04/02/2026  72.924
# 2    04/01/2026  76.078
# 3    03/31/2026  74.919
# 4    03/30/2026  70.569
# ..          ...     ...
# 249  04/11/2025  31.910
# 250  04/10/2025  30.759
# 251  04/09/2025  30.415
# 252  04/08/2025  29.686
# 253  04/07/2025  29.604
#
# [254 rows x 2 columns]

# %%
silver2 = silver2.iloc[::-1]
silver2 = silver2.reset_index(drop = True)
silver2
# Out:
#            Date   Price
# 0    04/07/2025  29.604
# 1    04/08/2025  29.686
# 2    04/09/2025  30.415
# 3    04/10/2025  30.759
# 4    04/11/2025  31.910
# ..          ...     ...
# 249  03/30/2026  70.569
# 250  03/31/2026  74.919
# 251  04/01/2026  76.078
# 252  04/02/2026  72.924
# 253  04/06/2026  72.847
#
# [254 rows x 2 columns]

# %%
silver2["Date"] = pd.to_datetime(silver2["Date"], format = "%m/%d/%Y")
silver2["Date"] = silver2["Date"].dt.strftime("%m-%d-%Y")
silver2
# Out:
#            Date   Price
# 0    04-07-2025  29.604
# 1    04-08-2025  29.686
# 2    04-09-2025  30.415
# 3    04-10-2025  30.759
# 4    04-11-2025  31.910
# ..          ...     ...
# 249  03-30-2026  70.569
# 250  03-31-2026  74.919
# 251  04-01-2026  76.078
# 252  04-02-2026  72.924
# 253  04-06-2026  72.847
#
# [254 rows x 2 columns]

# %%
silver = pd.concat([silver1, silver2], axis = "rows")
eth.drop_duplicates(subset = "Date", keep = "first")
silver = silver.rename(columns = {"Price" : "Silver Price"})
silver
# Out:
#            Date  Silver Price
# 0    08-30-2000         4.930
# 1    08-31-2000         5.003
# 2    09-01-2000         5.004
# 3    09-05-2000         4.998
# 4    09-06-2000         4.983
# ..          ...           ...
# 249  03-30-2026        70.569
# 250  03-31-2026        74.919
# 251  04-01-2026        76.078
# 252  04-02-2026        72.924
# 253  04-06-2026        72.847
#
# [6614 rows x 2 columns]

# %%
silver["Silver Percent Change Rate"] = (1 + silver["Silver Price"].pct_change()) * 100
silver
# Out:
#            Date  Silver Price  Silver Percent Change Rate
# 0    08-30-2000         4.930                         NaN
# 1    08-31-2000         5.003                  101.480729
# 2    09-01-2000         5.004                  100.019996
# 3    09-05-2000         4.998                   99.880095
# 4    09-06-2000         4.983                   99.699873
# ..          ...           ...                         ...
# 249  03-30-2026        70.569                  101.107513
# 250  03-31-2026        74.919                  106.164180
# 251  04-01-2026        76.078                  101.547004
# 252  04-02-2026        72.924                   95.854255
# 253  04-06-2026        72.847                   99.894411
#
# [6614 rows x 3 columns]

# %%
solana1
# Out:
#        datetime      open      high       low     close      volume  \
# 0     8/11/2020    2.8500    3.5208    2.8433    3.2985  1552384.78
# 1     8/12/2020    3.2985    3.9289    3.0800    3.7558  1737042.95
# 2     8/13/2020    3.7500    4.1387    3.5003    3.7300  1685759.24
# 3     8/14/2020    3.7207    3.7676    3.3210    3.4099  1474161.79
# 4     8/15/2020    3.4181    3.7400    3.1500    3.1730  1070233.20
# ...         ...       ...       ...       ...       ...         ...
# 1306   3/9/2024  144.7900  149.1500  143.5400  144.2900  3686876.81
# 1307  3/10/2024  144.3000  148.5000  140.4300  144.3900  4489519.25
# 1308  3/11/2024  144.3900  150.2000  136.4900  148.8300  7743384.35
# 1309  3/12/2024  148.8300  155.0000  141.5000  151.0500  8930538.00
# 1310  3/13/2024  151.0600  166.7300  148.7100  163.9000  7627285.95
#
#       Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9 Unnamed: 10
# 0            NaN         NaN         NaN         NaN         NaN
# 1            NaN         NaN         NaN         NaN         NaN
# 2            NaN         NaN         NaN         NaN         NaN
# 3            NaN         NaN         NaN         NaN         NaN
# 4            NaN         NaN         NaN         NaN         NaN
# ...          ...         ...         ...         ...         ...
# 1306         NaN         NaN         NaN         NaN         NaN
# 1307         NaN         NaN         NaN         NaN         NaN
# 1308         NaN         NaN         NaN         NaN         NaN
# 1309         NaN         NaN         NaN         NaN         NaN
# 1310         NaN         NaN         NaN         NaN         NaN
#
# [1311 rows x 11 columns]

# %%
solana1 = solana1[["datetime", "close"]]
solana1 = solana1.rename(columns = {"datetime" : "Date", "close" : "Price"})
solana1
# Out:
#            Date     Price
# 0     8/11/2020    3.2985
# 1     8/12/2020    3.7558
# 2     8/13/2020    3.7300
# 3     8/14/2020    3.4099
# 4     8/15/2020    3.1730
# ...         ...       ...
# 1306   3/9/2024  144.2900
# 1307  3/10/2024  144.3900
# 1308  3/11/2024  148.8300
# 1309  3/12/2024  151.0500
# 1310  3/13/2024  163.9000
#
# [1311 rows x 2 columns]

# %%
solana1["Date"] = pd.to_datetime(solana1["Date"], format = "%m/%d/%Y")
solana1["Date"] = solana1["Date"].dt.strftime("%m-%d-%Y")
solana1
# Out:
#             Date     Price
# 0     08-11-2020    3.2985
# 1     08-12-2020    3.7558
# 2     08-13-2020    3.7300
# 3     08-14-2020    3.4099
# 4     08-15-2020    3.1730
# ...          ...       ...
# 1306  03-09-2024  144.2900
# 1307  03-10-2024  144.3900
# 1308  03-11-2024  148.8300
# 1309  03-12-2024  151.0500
# 1310  03-13-2024  163.9000
#
# [1311 rows x 2 columns]

# %%
solana2
# Out:
#             Date  Close/Last  Volume     Open     High      Low
# 0     04/05/2026      81.968     NaN   80.545   82.903   81.689
# 1     04/04/2026      80.548     NaN   80.177   80.833   80.379
# 2     04/03/2026      79.852     NaN   78.895   80.197   78.893
# 3     04/02/2026      79.120     NaN   79.006   79.761   78.893
# 4     04/01/2026      79.011     NaN   83.377   81.760   78.395
# ...          ...         ...     ...      ...      ...      ...
# 1304  02/04/2022     115.587     NaN  102.527  115.856  110.340
# 1305  02/03/2022     102.437     NaN   98.188  103.842  100.388
# 1306  02/02/2022      98.576     NaN  109.298  103.073   96.848
# 1307  02/01/2022     109.519     NaN  106.139  112.137  108.338
# 1308  01/31/2022     105.630     NaN   89.892  108.008   99.236
#
# [1309 rows x 6 columns]

# %%
solana2 = solana2[["Date", "Close/Last"]]
solana2 = solana2.rename(columns = {"Close/Last" : "Price"})
solana2
# Out:
#             Date    Price
# 0     04/05/2026   81.968
# 1     04/04/2026   80.548
# 2     04/03/2026   79.852
# 3     04/02/2026   79.120
# 4     04/01/2026   79.011
# ...          ...      ...
# 1304  02/04/2022  115.587
# 1305  02/03/2022  102.437
# 1306  02/02/2022   98.576
# 1307  02/01/2022  109.519
# 1308  01/31/2022  105.630
#
# [1309 rows x 2 columns]

# %%
solana2 = solana2.iloc[::-1]
solana2 = solana2.reset_index(drop = True)
solana2
# Out:
#             Date    Price
# 0     01/31/2022  105.630
# 1     02/01/2022  109.519
# 2     02/02/2022   98.576
# 3     02/03/2022  102.437
# 4     02/04/2022  115.587
# ...          ...      ...
# 1304  04/01/2026   79.011
# 1305  04/02/2026   79.120
# 1306  04/03/2026   79.852
# 1307  04/04/2026   80.548
# 1308  04/05/2026   81.968
#
# [1309 rows x 2 columns]

# %%
solana2["Date"] = pd.to_datetime(solana2["Date"], format = "%m/%d/%Y")
solana2["Date"] = solana2["Date"].dt.strftime("%m-%d-%Y")
solana2
# Out:
#             Date    Price
# 0     01-31-2022  105.630
# 1     02-01-2022  109.519
# 2     02-02-2022   98.576
# 3     02-03-2022  102.437
# 4     02-04-2022  115.587
# ...          ...      ...
# 1304  04-01-2026   79.011
# 1305  04-02-2026   79.120
# 1306  04-03-2026   79.852
# 1307  04-04-2026   80.548
# 1308  04-05-2026   81.968
#
# [1309 rows x 2 columns]

# %%
solana = pd.concat([solana1, solana2], axis = "rows")
solana.drop_duplicates(subset = "Date", keep = "first")
solana = solana.rename(columns = {"Price" : "Solana Price"})
solana
# Out:
#             Date  Solana Price
# 0     08-11-2020        3.2985
# 1     08-12-2020        3.7558
# 2     08-13-2020        3.7300
# 3     08-14-2020        3.4099
# 4     08-15-2020        3.1730
# ...          ...           ...
# 1304  04-01-2026       79.0110
# 1305  04-02-2026       79.1200
# 1306  04-03-2026       79.8520
# 1307  04-04-2026       80.5480
# 1308  04-05-2026       81.9680
#
# [2620 rows x 2 columns]

# %%
solana["Solana Percent Change Rate"] = (1 + solana["Solana Price"].pct_change()) * 100
solana
# Out:
#             Date  Solana Price  Solana Percent Change Rate
# 0     08-11-2020        3.2985                         NaN
# 1     08-12-2020        3.7558                  113.863878
# 2     08-13-2020        3.7300                   99.313062
# 3     08-14-2020        3.4099                   91.418231
# 4     08-15-2020        3.1730                   93.052582
# ...          ...           ...                         ...
# 1304  04-01-2026       79.0110                   94.812442
# 1305  04-02-2026       79.1200                  100.137955
# 1306  04-03-2026       79.8520                  100.925177
# 1307  04-04-2026       80.5480                  100.871612
# 1308  04-05-2026       81.9680                  101.762924
#
# [2620 rows x 3 columns]

# %%
#xmag

# %% [markdown]
# I accidentally saved over the orginal XMAG file on my computer but the correct orginal file is still on Github.

# %%
#xmag = xmag[["Date", "XMAG Price"]]
#xmag = xmag.rename(columns = {"Close/Last" : "XMAG Price"})
#xmag

# %%
#xmag = xmag.iloc[::-1]
#xmag = xmag.reset_index(drop = True)
#xmag

# %%
#xmag["Date"] = pd.to_datetime(xmag["Date"], format = "%m/%d/%Y")
#xmag["Date"] = xmag["Date"].dt.strftime("%m-%d-%Y")
#xmag

# %%
xmag
# Out:
#      Unnamed: 0        Date  XMAG Price
# 0             0  10-22-2024     20.0000
# 1             1  10-23-2024     19.8758
# 2             2  10-24-2024     19.8300
# 3             3  10-25-2024     19.7700
# 4             4  10-28-2024     19.8400
# ..          ...         ...         ...
# 362         362  04-06-2026     22.5047
# 363         363  04-07-2026     22.5000
# 364         364  04-08-2026     23.0421
# 365         365  04-09-2026     23.1250
# 366         366  04-10-2026     22.9731
#
# [367 rows x 3 columns]

# %%
xmag = xmag[["Date", "XMAG Price"]]
xmag
# Out:
#            Date  XMAG Price
# 0    10-22-2024     20.0000
# 1    10-23-2024     19.8758
# 2    10-24-2024     19.8300
# 3    10-25-2024     19.7700
# 4    10-28-2024     19.8400
# ..          ...         ...
# 362  04-06-2026     22.5047
# 363  04-07-2026     22.5000
# 364  04-08-2026     23.0421
# 365  04-09-2026     23.1250
# 366  04-10-2026     22.9731
#
# [367 rows x 2 columns]

# %%
xmag["XMAG Percent Change Rate"] = (1 + xmag["XMAG Price"].pct_change()) * 100
xmag
# Out:
#            Date  XMAG Price  XMAG Percent Change Rate
# 0    10-22-2024     20.0000                       NaN
# 1    10-23-2024     19.8758                 99.379000
# 2    10-24-2024     19.8300                 99.769569
# 3    10-25-2024     19.7700                 99.697428
# 4    10-28-2024     19.8400                100.354072
# ..          ...         ...                       ...
# 362  04-06-2026     22.5047                100.479971
# 363  04-07-2026     22.5000                 99.979115
# 364  04-08-2026     23.0421                102.409333
# 365  04-09-2026     23.1250                100.359776
# 366  04-10-2026     22.9731                 99.343135
#
# [367 rows x 3 columns]

# %% [markdown]
# Below, I export all my wrangled data as csv files to save my progress and to make future work easier.

# %%
#xmag.to_csv("xmag_final.csv")
#solana.to_csv("solana_final.csv")
#silver.to_csv("silver_final.csv")
#spgold.to_csv("spgold_final.csv")
#spcomp1.to_csv("spcomp_final.csv")
#tsla.to_csv("tsla_final.csv")
#nvda.to_csv("nvda_final.csv")
#msft.to_csv("msft_final.csv")
#meta.to_csv("googl_final.csv")
#comp.to_csv("NASDAQ_Composite_final.csv")
#appl.to_csv("appl_final.csv")
#amzn.to_csv("amzn_final.csv")
#eth.to_csv("eth_final.csv")
#dow.to_csv("Dow_Jones_Composite_final.csv")
#cpi.to_csv("cpi_final.csv")
#oil.to_csv("oil_final.csv")
#bitcoin.to_csv("bitcoin_final.csv")
